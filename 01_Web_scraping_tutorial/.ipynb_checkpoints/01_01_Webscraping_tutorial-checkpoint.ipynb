# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import json
import numpy as np
from datetime import datetime
import requests

# %% [markdown]
# # Extracting data from single listing

# %% [markdown]
# Let's start with extracting most interesting data from a single listing. Once we manage to do that scraping multiple offers should not be an obstacle. On the other hand, creating whole pipeline to extract multiple offers and failing at the end would be a waste of time.

# %%
# url of first listing
listing_url = 'https://www.rightmove.co.uk/properties/97077389#/'

# %%
# First request is the moment of truth - if we do not receive Response [200] it probably means that we cannot scrape this website
requests.get(listing_url)
# Out:
# <Response [200]>

# %%
# Opening the url with BeautifulSoup and investigating where we can find the key data
page = requests.get(listing_url)
bs = BeautifulSoup(page.text, 'lxml')
bs.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <title>2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3</title>
# <meta content="width=device-width, shrink-to-fit=no, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3 - Rightmove." name="description"/>
# <!-- Favicons -->
# <link href="//www.rightmove.co.uk/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="Rightmove" name="apple-mobile-web-app-title"/>
# <meta content="Rightmove" name="application-name"/>
# <meta content="#262637" name="theme-color"/>
# <meta content="http://www.rightmove.co.uk/properties/97077389" property="og:url"/>
# <meta content="Check out this 2 bedroom flat for rent on Rightmove" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3 £2,817 pcm. Marketed by Draker Lettings , Sloane Square" property="og:description"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_01_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_02_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_03_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_04_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_05_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_06_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_07_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_08_0000.jpg/" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_09_0000.jpg/" property="og:image"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="Rightmove.co.uk" property="og:site_name"/>
# <meta content="rightmove.plc" property="og:admins"/>
# <meta content="485764298115191" property="og:app_id"/>
# <meta content="2911111" property="twitter:account_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_01_0000.jpg" name="twitter:image:src"/>
# <meta content="@rightmove" name="twitter:site"/>
# <meta content="http://www.rightmove.co.uk/properties/97077389" name="twitter:url"/>
# <meta content="Check out this 2 bedroom flat for rent on Rightmove" name="twitter:title"/>
# <meta content="2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3 £2,817 pcm. Marketed by Draker Lettings , Sloane Square" name="twitter:description"/>
# <link as="font" href="/ps/fonts/effra/Effra_WLatn_Md.woff2" rel="preload" type="font/woff2"/>
# <link as="font" href="/ps/fonts/effra/Effra_WLatn_Rg.woff2" rel="preload" type="font/woff2"/>
# <style>
#         @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Md.eot'); /* IE9 Compat Modes */
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Md.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff2') format('woff2'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff') format('woff');
#             font-style: normal;
#             font-weight: 500;
#             font-display: swap;
#         }
#         @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Rg.eot');
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Rg.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff2') format('woff2'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff') format('woff');
#             font-style: normal;
#             font-weight: normal;
#             font-display: swap;
#         }
#     </style>
# <link as="style" data-chunk="shared" href="/properties/assets/shared.8b5e7fab0373f0239fcb.css" rel="preload"/>
# <link as="script" data-chunk="shared" href="/properties/assets/shared.8b5e7fab0373f0239fcb.js" rel="preload"/>
# <link as="script" data-chunk="mainPage" href="/properties/assets/vendors~mainPage.f49aaf1320b02755d04d.js" rel="preload"/>
# <link as="style" data-chunk="mainPage" href="/properties/assets/floorplanPage~mainPage~mediaPage.cea5afe34cc435f0ae97.css" rel="preload"/>
# <link as="script" data-chunk="mainPage" href="/properties/assets/floorplanPage~mainPage~mediaPage.cea5afe34cc435f0ae97.js" rel="preload"/>
# <link as="style" data-chunk="mainPage" href="/properties/assets/mainPage.d9869b1336869354c9f2.css" rel="preload"/>
# <link as="script" data-chunk="mainPage" href="/properties/assets/mainPage.d9869b1336869354c9f2.js" rel="preload"/>
# <link data-chunk="shared" href="/properties/assets/shared.8b5e7fab0373f0239fcb.css" rel="stylesheet"/>
# <link data-chunk="mainPage" href="/properties/assets/floorplanPage~mainPage~mediaPage.cea5afe34cc435f0ae97.css" rel="stylesheet"/>
# <link data-chunk="mainPage" href="/properties/assets/mainPage.d9869b1336869354c9f2.css" rel="stylesheet"/>
# <!-- Google Optimize -->
# <!-- Anti-flicker snippet (recommended)  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#     (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',4000,
#     {'GTM-M5C7HFR':true});function gtag() {dataLayer.push(arguments)};</script>
# <script async="" onerror="dataLayer.hide.end &amp;&amp; dataLayer.hide.end()" src="https://www.googleoptimize.com/optimize.js?id=GTM-M5C7HFR"></script>
# <!-- End Google Optimize -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl+'&gtm_auth=g2ndo_352oWlGwJG7HHfyw&gtm_preview=env-7&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
#     })(window,document,'script','rmDataLayer','GTM-T4524Q');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-T4524Q&amp;gtm_auth=g2ndo_352oWlGwJG7HHfyw&amp;gtm_preview=env-7&amp;gtm_cookies_win=x" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Man
# </symbol>
# <symbol id="chevron-line" viewbox="0 0 16 16">
# <path d="M8 10.293l5.146-5.147a.5.5 0 0 1 .708.708l-5.5 5.5a.5.5 0 0 1-.708 0l-5.5-5.5a.5.5 0 1 1 .708-.708L8 10.293z"></path>
# </symbol>
# <symbol id="chevron" viewbox="0 0 7.6 4.1">
# <path d="M4 4L7.5.5c.2-.2.1-.5-.2-.5h-7C0 0-.1.3.1.5L3.6 4c.1.1.3.1.4 0z"></path>
# </symbol>
# <symbol id="camera" viewbox="0 0 16 13">
# <path d="M5 0v1h8.5A2.5 2.5 0 0116 3.5v8a1.5 1.5 0 01-1.5 1.5h-13A1.5 1.5 0 010 11.5v-8a2.5 2.5 0 012-2.45V0h3zm8.5 2h-11A1.5 1.5 0 001 3.5v8a.5.5 0 00.5.5h13a.5.5 0 00.5-.5v-8A1.5 1.5 0 0013.5 2zM8 4a3 3 0 110 6 3 3 0 010-6zm0 1a2 2 0 100 4 2 2 0 000-4zm6-1v1h-2V4h2z"></path>
# </symbol>
# <symbol id="floorplan" viewbox="0 0 14 14">
# <path d="M13 7v5a1 1 0 01-1 1H6v1h6a2 2 0 002-2V2a2 2 0 00-2-2H2a2 2 0 00-2 2v10a2 2 0 002 2h2v-1H2a1 1 0 01-1-1v-2h7V9H1V2a1 1 0 011-1h2v5h1V1h7a1 1 0 011 1v4H8v1h5z"></path>
# </symbol>
# <symbol id="virtual-tour" viewbox="0 0 16 14">
# <path d="M12 0a4 4 0 014 4v6a4 4 0 01-4 4H4a4 4 0 01-4-4V4a4 4 0 014-4h8zm0 1H4a3 3 0 00-3 3v6a3 3 0 003 3h8a3 3 0 003-3V4a3 3 0 00-3-3zM6.765 4.076l4 2.5a.5.5 0 010 .848l-4 2.5A.5.5 0 016 9.5v-5a.5.5 0 01.765-.424zM7 5.402v3.196L9.557 7 7 5.402z"></path>
# </symbol>
# <symbol id="play-icon" viewbox="0 0 16 16">
# <g fill="none" fill-rule="evenodd">
# <path d="M4 1h8a4 4 0 014 4v6a4 4 0 01-4 4H4a4 4 0 01-4-4V5a4 4 0 014-4z" fill="#262637" opacity=".848"></path>
# <path d="M10.265 8.424l-4 2.5a.5.5 0 01-.765-.425V5.501a.5.5 0 01.765-.424l4 2.5a.5.5 0 010 .847z" fill="#FFF" fill-rule="nonzero"></path>
# </g>
# </symbol>
# <symbol id="arrow-left" viewbox="0 0 17 13">
# <path d="M2.707 7l5.147 5.146-.708.708L.793 6.5 7.146.146l.708.708L2.707 6H17v1z"></path>
# </symbol>
# <symbol id="close" viewbox="0 0 16 16">
# <path d="M7.293 8L1.146 1.854l.708-.708L8 7.293l6.146-6.147.708.708L8.707 8l6.147 6.146-.708.708L8 8.707l-6.146 6.147-.708-.708L7.293 8z"></path>
# </symbol>
# <symbol id="email" viewbox="0 0 16 16">
# <path d="M1.143 3H1v9a1 1 0 001 1h12a1 1 0 001-1V3h-.143L8 9 1.143 3zM0 2h16v10a2 2 0 01-2 2H2a2 2 0 01-2-2V2zm2.703 1L8 7.683 13.297 3H2.703z"></path>
# </symbol>
# <symbol id="earth" viewbox="0 0 16 16">
# <path d="M8 0a8 8 0 110 16A8 8 0 018 0zM3.459 2.673l.76.382a1.5 1.5 0 01.73 1.867l-.057.132-1.007 2.06a.5.5 0 00.149.62l.076.047 3.232 1.615a1.5 1.5 0 01.737 1.86l-.056.133-1.647 3.422a7 7 0 008.5-8.136l-.346.68a1.5 1.5 0 01-1.854.73l-.131-.056-1.189-.57a1.5 1.5 0 01-.691-1.894l.061-.131.458-.872a.5.5 0 00-.16-.62l-.077-.046-5.268-2.502a6.992 6.992 0 00-2.22 1.279zM1 8a7.002 7.002 0 004.413 6.506l1.71-3.551a.5.5 0 00-.152-.617l-.076-.047-3.232-1.615a1.5 1.5 0 01-.734-1.869l.057-.132 1.007-2.06a.5.5 0 00-.148-.62L3.77 3.95 2.71 3.415A6.973 6.973 0 001 8zm7-7c-.25 0-.495.013-.738.038l4.114 1.955a1.5 1.5 0 01.767 1.865l-.056.133-.476.908a.5.5 0 00.134.626l.093.058 1.138.544a.5.5 0 00.615-.15l.047-.075.818-1.612A7.002 7.002 0 008 1z"></path>
# </symbol>
# <symbol id="phone" viewbox="0 0 16 16">
# <path d="M2.53 2.975a2.842 2.842 0 00-.427 3.472l.578.963c1.308 2.18 3.84 4.713 6.02 6.021l.964.578a2.842 2.842 0 003.472-.428l1.414-1.414-2.828-2.828-1.83 1.83-.565-.161c-1.55-.44-3.498-2.31-4.04-3.827l-.306-.86L6.844 4.46l-2.9-2.9L2.53 2.976zm-.707-.707L3.237.854a1 1 0 011.414 0l2.9 2.899a1 1 0 010 1.414L6.136 6.58l.095.264c.432 1.213 2.131 2.85 3.37 3.2l1.414-1.413a1 1 0 011.415 0l2.828 2.828a1 1 0 010 1.414l-1.414 1.415a3.842 3.842 0 01-4.694.577l-.963-.577c-2.321-1.393-4.971-4.043-6.364-6.364l-.578-.963a3.842 3.842 0 01.578-4.694z"></path>
# </symbol>
# <symbol id="approx-location-circle" viewbox="0 0 320 320">
# <circle cx="160" cy="160" r="150" stroke-width="4"></circle>
# </symbol>
# <symbol id="map-pin" viewbox="0 0 12 16">
# <path d="M6 0a6 6 0 016 6c0 4-2 7.333-6 10-4-2.667-6-6-6-10a6 6 0 016-6zm0 1a5 5 0 00-5 5c0 3.46 1.639 6.368 5 8.784C9.361 12.368 11 9.46 11 6a5 5 0 00-5-5zm0 2a3 3 0 110 6 3 3 0 010-6zm0 1a2 2 0 100 4 2 2 0 000-4z"></path>
# </symbol>
# <symbol id="streetview" viewbox="0 0 15 16">
# <path d="M7.5 5A3.5 3.5 0 0111 8.5V11h-1v.054c2.97.318 5 1.16 5 2.408C15 15.029 11.664 16 7.5 16S0 15.029 0 13.462c0-1.248 2.032-2.09 5-2.408V11H4V8.5A3.5 3.5 0 017.5 5zM1 13.462C1 14.146 3.932 15 7.5 15s6.5-.854 6.5-1.538c0-.47-1.625-1.125-3.999-1.4L10 14H5v-1.939c-2.375.276-4 .93-4 1.4zM7.5 6a2.5 2.5 0 00-2.495 2.336L5 8.5V10h1v3h3v-3h1V8.5a2.5 2.5 0 00-2.336-2.495L7.5 6zm0-6a2.5 2.5 0 110 5 2.5 2.5 0 010-5zm0 1a1.5 1.5 0 100 3 1.5 1.5 0 000-3z"></path>
# </symbol>
# <symbol id="bed" viewbox="0 0 16 15">
# <path d="M15 8.012H2.5a1.5 1.5 0 00-1.5 1.5v1.5h14v-3zm-10-1v-3a1 1 0 011-1h7a3 3 0 013 3v8h-1v-2H1v2H0V0h1v7.512c.418-.314.937-.5 1.5-.5H5zm1 0h9v-1a2 2 0 00-2-2H6v3zm-3 0a2 2 0 110-4 2 2 0 010 4zm0-1a1 1 0 100-2 1 1 0 000 2z"></path>
# </symbol>
# <symbol id="bathroom" viewbox="0 0 15 16">
# <path d="M4.837 0a2.5 2.5 0 012.458 2.042A2.5 2.5 0 019.337 4.5a.5.5 0 01-.5.5h-4a.5.5 0 01-.5-.5c0-1.187.827-2.18 1.936-2.436a1.5 1.5 0 00-2.936.436V10h10.5a.5.5 0 01.485.621l-.432 1.728a3.493 3.493 0 01-1.11 1.803l.508 1.529-.948.316-.431-1.295a3.492 3.492 0 01-1.414.298H4.18c-.498 0-.976-.105-1.41-.296l-.432 1.297-.949-.317.51-1.529A3.493 3.493 0 01.784 12.35L.352 10.62A.5.5 0 01.837 10h1.5V2.5a2.5 2.5 0 012.5-2.5zm8.36 11H1.477l.277 1.106A2.5 2.5 0 004.18 14h6.315c.39 0 .763-.09 1.096-.253l-.007-.02.128-.043a2.499 2.499 0 001.208-1.578L13.197 11zm-4.36-3a.5.5 0 110 1 .5.5 0 010-1zm-2 0a.5.5 0 110 1 .5.5 0 010-1zm-2 0a.5.5 0 110 1 .5.5 0 010-1zm3-1a.5.5 0 110 1 .5.5 0 010-1zm-2 0a.5.5 0 110 1 .5.5 0 010-1zm1-1a.5.5 0 110 1 .5.5 0 010-1zm0-3a1.5 1.5 0 00-1.414 1h2.829a1.5 1.5 0 00-1.415-1z"></path>
# </symbol>
# <symbol id="exclamation-circle" viewbox="0 0 16 16">
# <path d="M8 0a8 8 0 110 16A8 8 0 018 0zm0 1a7 7 0 100 14A7 7 0 008 1zm0 9a1 1 0 110 2 1 1 0 010-2zm-.066-6a.874.874 0 01.857 1.046L8 9l-.897-3.96A.852.852 0 017.933 4z"></path>
# </symbol>
# <svg id="facebook" viewbox="0 0 32 32">
# <g fill="none" fill-rule="evenodd">
# <path d="M32 16.094C32 7.206 24.837 0 16 0S0 7.206 0 16.094c0 8.033 5.851 14.692 13.5 15.9V20.746H9.437v-4.653H13.5V12.55c0-4.034 2.389-6.262 6.043-6.262 1.751 0 3.582.314 3.582.314v3.96h-2.018c-1.987 0-2.607 1.241-2.607 2.514v3.02h4.438l-.71 4.652H18.5v11.246c7.649-1.208 13.5-7.867 13.5-15.9" fill="#1877F2"></path>
# <path d="M22.083 20.956l.725-4.49H18.27v-2.914c0-1.228.634-2.426 2.667-2.426H23V7.303S21.127 7 19.337 7c-3.739 0-6.182 2.15-6.182 6.044v3.422H9v4.49h4.155v10.855a17.352 17.352 0 005.114 0V20.956h3.814" fill="#FFF"></path>
# </g>
# </svg>
# <symbol id="share" viewbox="0 0 14 14"><defs></defs>
# <path d="M20 33s2.644-2.111 3.886-2.431a15.419 15.419 0 002.914-1.074c5.169-2.522 8.73-7.828 8.73-13.966C35.53 6.953 28.576 0 20 0 11.423 0 4.47 6.953 4.47 15.53c0 6.178 3.609 11.514 8.833 14.015.918.439 1.886.79 2.892 1.044C17.413 30.896 20 33 20 33z" fill="#262637" stroke="#FFF"></path>
# <path d="M14 14.46V21h12v-6.54l-6-5.143-6 5.143zm-.65-.76L20 8l6.65 5.7a1 1 0 01.35.76V21a1 1 0 01-1 1H14a1 1 0 01-1-1v-6.54a1 1 0 01.35-.76z" fill="#FFF"></path>
# <circle cx="20" cy="37" fill="#262637" r="3.5" stroke="#FFF"></circle>
# </g>
# </symbol>
# <symbol id="selected-property-school-map-pin" viewbox="0 0 48 62">
# <g fill="none" fill-rule="evenodd" transform="translate(-6 1)">
# <path d="M30 49.5s3.966-3.167 5.83-3.647a23.128 23.128 0 004.37-1.611c7.753-3.782 13.094-11.741 13.094-20.948C53.294 10.43 42.865 0 30 0S6.706 10.43 6.706 23.294c0 9.268 5.412 17.272 13.249 21.023a23.125 23.125 0 004.338 1.567C26.12 46.344 30 49.5 30 49.5z" fill="#262637" stroke="#FFF"></path>
# <path d="M30 42.75s2.945-2.351 4.328-2.708a17.17 17.17 0 003.245-1.196c5.756-2.808 9.721-8.717 9.721-15.552C47.294 13.743 39.551 6 30 6s-17.294 7.743-17.294 17.294c0 6.88 4.018 12.823 9.836 15.608 1.022.49 2.1.881 3.221 1.163C27.12 40.407 30 42.75 30 42.75z" fill="#262637" stroke="#FFF" stroke-width="2"></path>
# <path d="M21 21.69v9.81h18v-9.81l-9-7.714-9 7.714zm-.976-1.139L30 12l9.976 8.551a1.5 1.5 0 01.524 1.139v9.81A1.5 1.5 0 0139 33H21a1.5 1.5 0 01-1.5-1.5v-9.81a1.5 1.5 0 01.524-1.139z" fill="#FFF"></path>
# <circle cx="30" cy="55.5" fill="#262637" r="5" stroke="#FFF"></circle>
# </g>
# </symbol>
# <symbol id="house" viewbox="0 0 16 16">
# <path d="M8.035.3l7.736 4.125-.471.883-.765-.408v10.217a.5.5 0 01-.41.492l-.09.008h-12a.5.5 0 01-.492-.41l-.008-.09V4.899l-.764.409L.3 4.425 8.035.3zm0 1.134l-5.5 2.933v10.25h4.5v-2.25a1 1 0 011.994-.117l.006.117v2.25h4.5V4.367l-5.5-2.933z" fill="#262637" fill-rule="nonzero"></path>
# </symbol>
# <symbol id="open-window" viewbox="0 0 15 14">
# <g fill="#11828D" fill-rule="evenodd">
# <path d="M13 13V7h1v7H0V0h7v1H1v12z"></path>
# <path d="M9.732.064h4.328v4.329h-1V1.77L7.903 6.928l-.708-.707 5.156-5.157h-2.62v-1z"></path>
# </g>
# </symbol>
# <symbol id="medal" viewbox="0 0 32 40">
# <path d="M32 0v5.414L23.414 14H20v2.683c4.661 1.648 8 6.092 8 11.317 0 6.627-5.373 12-12 12S4 34.627 4 28c0-5.225 3.34-9.67 8-11.317V14H8.586L0 5.414V0h32zM16 18c-5.523 0-10 4.477-10 10s4.477 10 10 10 10-4.477 10-10-4.477-10-10-10zm2-4h-4v2.166a12.081 12.081 0 014 0V14zM4.585 2H2v2.586L9.414 12h5.171l-10-10zM30 2h-2.586l-10 10h5.172L30 4.586V2zm-5.416 0H7.415L16 10.585 24.584 2z" fill="#262637" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="school-filters" viewbox="0 0 17 20">
# <path d="M5.875 14.375c1.165 0 2.144.797 2.421 1.876l8.204-.001v1.25H8.296a2.501 2.501 0 01-4.842 0H.875v-1.25h2.579a2.501 2.501 0 012.421-1.875zm0 1.25a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm6.25-8.125c1.165 0 2.144.797 2.421 1.876l1.954-.001v1.25h-1.954a2.501 2.501 0 01-4.842 0H1.5v-1.25h8.204A2.501 2.501 0 0112.125 7.5zm0 1.25a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zM5.875.625c1.165 0 2.144.797 2.421 1.876L16.5 2.5v1.25H8.296a2.501 2.501 0 01-4.842 0H1.5V2.5h1.954A2.501 2.501 0 015.875.626zm0 1.25a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5z" fill="#262637" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="info-icon" viewbox="0 0 14 14">
# <path d="M7 0a7 7 0 110 14A7 7 0 017 0zm0 .875a6.125 6.125 0 100 12.25A6.125 6.125 0 007 .875zm0 5.688c.242 0 .438.195.438.437v3.5a.437.437 0 11-.875 0V7c0-.242.195-.438.437-.438zM7 3.5a.875.875 0 110 1.75.875.875 0 010-1.75z" fill="#313242" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="rightmove-icon" viewbox="0 0 20 20">
# <path d="M14.41 17.73h2.527V9.79L9.99 3.79 3.044 9.79v7.942H5.57l4.44-3.85 4.4 3.85zM17.234 20h-3.631L9.99 16.86 6.36 20H2.728c-.513 0-.987-.203-1.342-.567a2.005 2.005 0 01-.553-1.398l.02-8.388c0-.527.197-1.013.553-1.378l.079-.081L9.99.833l8.604 7.436c.356.365.553.851.553 1.378l.02 8.388c0 .526-.198 1.013-.553 1.398-.355.385-.868.567-1.381.567z" fill="#53535F" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="avatar-person" viewbox="0 0 10 16">
# <path d="M5 0a4 4 0 110 8 4 4 0 010-8zm0 1a3 3 0 100 6 3 3 0 000-6zm-1.5 9A2.5 2.5 0 001 12.5V14a1 1 0 001 1h6a1 1 0 001-1v-1.5A2.5 2.5 0 006.5 10h-3zm0-1h3a3.5 3.5 0 013.5 3.5V14a2 2 0 01-2 2H2a2 2 0 01-2-2v-1.5A3.5 3.5 0 013.5 9z" fill="#262637" fill-rule="evenodd"></path>
# </symbol>
# </svg>
# </div>
# <header class="globalHeader globalHeader__signedOut" id="globalHeader">
# <div class="globalHeader__header">
# <a class="globalHeader__logo globalHeader__logoMobile" href="/" title="Go to Rightmove homepage">
# <svg aria-label="Rightmove logo" role="img"><use xlink:href="#rightmove-icon-logo"></use></svg>
# </a>
# <a class="globalHeader__logo globalHeader__logoDesktop" href="/" title="Go to Rightmove homepage">
# <svg aria-label="Rightmove logo" role="img"><use xlink:href="#rightmove-with-icon-logo"></use></svg>
# </a>
# <div class="globalHeader__mobileTitle">Property Details</div>
# <div class="globalHeader__nav">
# <div class="globalHeader__navItem globalHeader__buy">
# <a aria-expanded="false" aria-haspopup="true" href="/property-for-sale.html">Buy</a>
# <div class="globalHeader__navSubNav">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/property-for-sale.html">Property for sale</a></li>
# <li><a href="/new-homes-for-sale.html">New homes for sale</a></li>
# </ul>
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/property-valuation.html">Property valuation</a></li>
# <li><a href="/property-investment.html">Investors</a></li>
# <li><a href="/mortgages/">Mortgages</a></li>
# </ul>
# </div>
# </div>
# <div class="globalHeader__navItem globalHeader__rent">
# <a aria-expanded="false" aria-haspopup="true" href="/property-to-rent.html">Rent</a>
# <div class="globalHeader__navSubNav">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/property-to-rent">Property to rent</a></li>
# <li><a href="/student-accommodation.html">Student property to rent</a></li>
# </ul>
# </div>
# </div>
# <div class="globalHeader__navItem globalHeader__findAgent">
# <a aria-expanded="false" aria-haspopup="true" href="/estate-agents.html">Find Agent</a>
# <div class="globalHeader__navSubNav">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/estate-agents.html">Find estate agents</a></li>
# <li><a href="/property-valuation.html">Property valuation</a></li>
# </ul>
# </div>
# </div>
# <div class="globalHeader__navItem globalHeader__housePrices">
# <a aria-expanded="false" aria-haspopup="true" href="/house-prices.html">House Prices</a>
# <div class="globalHeader__navSubNav">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/house-prices.html">Sold house prices</a></li>
# <li><a href="/property-valuation.html">Property valuation</a></li>
# </ul>
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/house-value.html">Price comparison report</a></li>
# <li><a href="/house-prices-in-my-area.html">Market trends</a></li>
# </ul>
# </div>
# </div>
# <div class="globalHeader__navItem globalHeader__commercial">
# <a aria-expanded="false" aria-haspopup="true" href="/commercial-property-to-let.html">Commercial</a>
# <div class="globalHeader__navSubNav">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/commercial-property-to-let.html">Commercial property to let</a></li>
# <li><a href="/commercial-property-for-sale.html">Commercial property for sale</a></li>
# </ul>
# </div>
# </div>
# <div class="globalHeader__navItem globalHeader__inspire">
# <a aria-expanded="false" aria-haspopup="true" href="/moving-stories.html">Inspire</a>
# <div class="globalHeader__navSubNav globalHeader__subNavReverse">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/moving-stories.html">Moving stories</a></li>
# <li><a href="/news">Property blog</a></li>
# </ul>
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/advice">Property advice</a></li>
# <li><a href="/news/house-price-index/">Housing trends</a></li>
# </ul>
# </div>
# </div>
# <div class="globalHeader__navItem globalHeader__overseas globalHeader__lastItem">
# <a aria-expanded="false" aria-haspopup="true" href="/overseas-property.html">Overseas</a>
# <div class="globalHeader__navSubNav globalHeader__subNavReverse">
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/overseas-property.html">Overseas properties for sale</a></li>
# <li><a href="/overseas-property/hot-properties.html">Hot properties</a></li>
# <li><a href="/overseas-property/in-Spain.html">Spain</a></li>
# </ul>
# <ul class="globalHeader__navSubNavCol">
# <li><a href="/overseas-property/in-France.html">France</a></li>
# <li><a href="/overseas-property/help-and-advice/research.html">Help and advice</a></li>
# <li><a href="/overseas-property/advertise.html">Sell overseas property</a></li>
# </ul>
# </div>
# </div>
# </div>
# <a class="globalHeader__myRm globalHeader__myRmSignedIn" href="/myrightmove.html" title="Go to My Rightmove">
# <span>My Rightmove</span>
# <svg aria-hidden="true" role="img"><use xlink:href="#account-silhouette"></use></svg>
# </a>
# <a class="globalHeader__myRm globalHeader__myRmSignedOut" href="/login.html?from=%2Fproperties%2F97077389&amp;hideFromParameterOnRegisterURI=true" title="Sign in to My Rightmove">
# <span>Sign In</span>
# <svg aria-hidden="true" role="img"><use xlink:href="#account-silhouette"></use></svg>
# </a>
# </div>
# <div class="globalHeader__navSubNavBackground"></div>
# <div aria-label="Close menu" class="globalHeader__navBackdrop" role="button" tabindex="0"></div>
# </header>
# <script>
#             (function () {
#                 // polyfill
#                 if (window.NodeList && !NodeList.prototype.forEach) {
#                     NodeList.prototype.forEach = Array.prototype.forEach;
#                 }
#
#                 var subNavBackground = document.querySelector('.globalHeader__navSubNavBackground');
#                 var backdrop = document.querySelector('.globalHeader__navBackdrop');
#                 var navItems = document.querySelectorAll('.globalHeader__navItem');
#                 var openedSubMenu = null;
#                 var mouseDown = false;
#
#                 function openSubNav(node) {
#                     node.classList.add('globalHeader__activeNav');
#                     subNavBackground.classList.add('globalHeader__navSubNavBackgroundOpen');
#                     backdrop.classList.add('globalHeader__navBackdropOpen');
#                     node.querySelector('a:first-child').setAttribute('aria-expanded', 'true');
#                     openedSubMenu = node;
#                 }
#
#                 function closeSubNav(node) {
#                     node.classList.remove('globalHeader__activeNav');
#                     subNavBackground.classList.remove('globalHeader__navSubNavBackgroundOpen');
#                     backdrop.classList.remove('globalHeader__navBackdropOpen');
#                     openedSubMenu = null;
# ...
# </ul>
# </div>
# <div class="globalFooter__menuGroup">
# <div aria-expanded="false" aria-label="Toggle Quick links submenu" class="globalFooter__menuGroupHeader" tabindex="0">
# <span>Quick links</span>
# <svg aria-hidden="true" class="globalFooter__chevron" role="img"><use xlink:href="#chevron-line"></use></svg>
# </div>
# <ul class="globalFooter__subMenu">
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/cheap-flats-to-rent.html" title="Cheap flats to rent">Cheap flats to rent</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/property-investment.html" title="Property investment">Property investment</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/cheap-houses-for-sale.html" title="Cheap houses for sale">Cheap houses for sale</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/overseas-property.html" title="Overseas">Overseas</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/estate-agents.html" title="Find an agent">Find an agent</a></li>
# <li class="globalFooter__subMenuItem globalFooter__subMenuItem--secondary"><a class="globalFooter__subMenuLink" href="/commercial-property-to-let.html" title="Commercial Property to Let">Commercial Property to Let</a></li>
# <li class="globalFooter__subMenuItem globalFooter__subMenuItem--secondary"><a class="globalFooter__subMenuLink" href="/commercial-property-for-sale.html" title="Commercial Property for Sale">Commercial Property for Sale</a></li>
# </ul>
# </div>
# <div class="globalFooter__menuGroup">
# <div aria-expanded="false" aria-label="Toggle Rightmove PLC submenu" class="globalFooter__menuGroupHeader" tabindex="0">
# <span>Rightmove PLC</span>
# <svg aria-hidden="true" class="globalFooter__chevron" role="img"><use xlink:href="#chevron-line"></use></svg>
# </div>
# <ul class="globalFooter__subMenu">
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="http://plc.rightmove.co.uk/about-us/" title="About">About</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="http://plc.rightmove.co.uk/media/" title="Press centre">Press centre</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="http://plc.rightmove.co.uk/investors/" title="Investor relations">Investor relations</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/rightmoveplc/rightmove-contacts.html" title="Contact us">Contact us</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="http://plc.rightmove.co.uk/careers" title="Careers">Careers</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/mobile-platforms.html" title="Mobile apps">Mobile apps</a></li>
# </ul>
# </div>
# <div class="globalFooter__menuGroup">
# <div aria-expanded="false" aria-label="Toggle Regions submenu" class="globalFooter__menuGroupHeader" tabindex="0">
# <span>Regions</span>
# <svg aria-hidden="true" class="globalFooter__chevron" role="img"><use xlink:href="#chevron-line"></use></svg>
# </div>
# <ul class="globalFooter__subMenu">
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/property/England.html" title="England">England</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/property/Scotland.html" title="Scotland">Scotland</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/property/Northern-Ireland.html" title="Northern Ireland">Northern Ireland</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/property/Wales.html" title="Wales">Wales</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/property/London.html" title="London">London</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/tube-map.html" title="London stations">London stations</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/overseas-property/in-Spain.html" title="Spain">Spain</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/overseas-property/in-France.html" title="France">France</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/overseas-property/in-Portugal.html" title="Portugal">Portugal</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/overseas-property.html" title="All Countries">All Countries</a></li>
# <li class="globalFooter__subMenuItem globalFooter__subMenuItem--secondary"><a class="globalFooter__subMenuLink" href="/major-cities.html" title="Major towns and cities">Major towns and cities</a></li>
# </ul>
# </div>
# <div class="globalFooter__menuGroup globalFooter__menuGroup">
# <div aria-expanded="false" aria-label="Toggle Professional submenu" class="globalFooter__menuGroupHeader" tabindex="0">
# <span>Professional</span>
# <svg aria-hidden="true" class="globalFooter__chevron" role="img"><use xlink:href="#chevron-line"></use></svg>
# </div>
# <ul class="globalFooter__subMenu">
# <li class="globalFooter__subMenuItem-black" id="fs-customer-link-menu-item">
# <a class="globalFooter__subMenuLink" href="https://rmplusportal.rightmove.co.uk" title="Rightmove Plus">Rightmove Plus</a>
# </li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/data/" title="Automated Valuations">Data Services</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/for-agents.html" title="Agents and Developers">Agents and Developers</a></li>
# <li class="globalFooter__subMenuItem"><a class="globalFooter__subMenuLink" href="/overseas-property/advertise.html" title="Agents and Developers">Overseas Agents and Developers</a></li>
# </ul>
# </div>
# </div>
# <div class="globalFooter__menuFooter">
# <div class="globalFooter__legal">
# <span class="globalFooter__legalTitle">This site:</span>
# <a class="globalFooter__legalLink" href="/site-map.html">Site map</a>
# <a class="globalFooter__legalLink globalFooter__legalLinkSecondary" href="/this-site/help.html">Help</a>
# <a class="globalFooter__legalLink optanon-show-settings-button optanon-toggle-display" href="/this-site/cookies.html" target="_blank">Cookies</a>
# <a class="globalFooter__legalLink globalFooter__legalLinkSecondary" href="/this-site/safety-and-security.html">Safety and security</a>
# <a class="globalFooter__legalLink" href="/this-site/terms-of-use.html">Terms of Use</a>
# <a class="globalFooter__legalLink" href="/this-site/privacy-policy.html">Privacy Policy</a>
# </div>
# <div class="globalFooter__cities">
# <span class="globalFooter__citiesHeader">Major cities and towns in the UK:</span>
# <div class="select-wrapper globalFooter__citiesSelectWrapper">
# <select aria-label="Major cities and towns in the UK" class="select globalFooter__citiesSelect" onchange="window.location.href = this.value" title="Major cities and towns in the UK">
# <option selected="selected" value="">Select (A-Z)</option>
# <optgroup label="United Kingdom:">
# <option value="/uk-property-search-a-be.html">A-Be</option>
# <option value="/uk-property-search-bl-bu.html">Bl-Bu</option>
# <option value="/uk-property-search-ca-ce.html">Ca-Ce</option>
# <option value="/uk-property-search-ch-con.html">Ch-Con</option>
# <option value="/uk-property-search-cor-cu.html">Cor-Cu</option>
# <option value="/uk-property-search-d.html">D</option>
# <option value="/uk-property-search-ea.html">Ea</option>
# <option value="/uk-property-search-ed-f.html">Ed-F</option>
# <option value="/uk-property-search-g.html">G</option>
# <option value="/uk-property-search-h.html">H</option>
# <option value="/uk-property-search-i-k.html">I-K</option>
# <option value="/uk-property-search-l.html">L</option>
# <option value="/uk-property-search-m-ne.html">M-Ne</option>
# <option value="/uk-property-search-no.html">No</option>
# <option value="/uk-property-search-o-r.html">O-R</option>
# <option value="/uk-property-search-sc-so.html">Sc-So</option>
# <option value="/uk-property-search-st-sw.html">St-Sw</option>
# <option value="/uk-property-search-t-v.html">T-V</option>
# <option value="/uk-property-search-wa-we.html">Wa-We</option>
# <option value="/uk-property-search-wi-wr.html">Wi-Wr</option>
# <option value="/uk-property-search-y.html">Y</option>
# <option value="/major-cities.html">Major cities in the UK</option>
# </optgroup>
# <optgroup label="London:">
# <option value="/property/London.html">London Property</option>
# <option value="/property-for-sale/London.html">London Property for Sale</option>
# <option value="/property-to-rent/London.html">London Property to Rent</option>
# <option value="/london-property-search-ba.html">Ba</option>
# <option value="/london-property-search-be-br.html">Be-Br</option>
# <option value="/london-property-search-c.html">C</option>
# <option value="/london-property-search-e-g.html">E-G</option>
# <option value="/london-property-search-ha.html">Ha</option>
# <option value="/london-property-search-hi-ho.html">Hi-Ho</option>
# <option value="/london-property-search-i-k.html">I-K</option>
# <option value="/london-property-search-l-m.html">L-M</option>
# <option value="/london-property-search-n-r.html">N-R</option>
# <option value="/london-property-search-s-t.html">S-T</option>
# <option value="/london-property-search-w.html">W</option>
# <option value="/london-popular-regions.html">Popular regions in London</option>
# </optgroup>
# <optgroup label="Houses:">
# <option value="/property-for-sale/B11.html">Houses for sale in B11</option>
# <option value="/property-for-sale/B9.html">Houses for sale in B9</option>
# <option value="/property-for-sale/Hu8.html">Houses for sale in HU8</option>
# <option value="/property-for-sale/Bl1.html">Houses for sale in BL1</option>
# <use xlink:href="#chevron"></use>
# </svg>
# </div>
# </div>
# </div>
# </footer>
# <script>
#         (function () {
#
#             var footerItems = document.querySelectorAll('.globalFooter__menuGroupHeader');
#             var resizeTimeout = null;
#
#             function closeAll() {
#                 footerItems.forEach(function (item) {
#                     item.parentNode.classList.remove('globalFooter__menuGroupOpen');
#                     item.setAttribute('aria-expanded', 'false');
#                 });
#             }
#
#             function itemClick(event) {
#                 var menuGroup = event.target.tagName === 'DIV' ? event.target.parentNode : event.target.parentNode.parentNode;
#
#                 if (menuGroup.classList.contains('globalFooter__menuGroupOpen')) {
#                     closeAll();
#                 } else {
#                     closeAll();
#                     menuGroup.classList.add('globalFooter__menuGroupOpen');
#                     event.target.setAttribute('aria-expanded', 'true');
#                 }
#             }
#
#             footerItems.forEach(function (item) {
#                 item.addEventListener('click', itemClick);
#             });
#
#             function toggleTabIndex() {
#                 if (window.innerWidth >= 768) {
#                     footerItems.forEach(function (item) {
#                         item.setAttribute('tabindex', '-1');
#                     });
#                 } else {
#                     footerItems.forEach(function (item) {
#                         item.setAttribute('tabindex', '0');
#                     });
#                 }
#             }
#
#             window.addEventListener('resize', function() {
#                 clearTimeout(resizeTimeout);
#                 resizeTimeout = setTimeout(toggleTabIndex, 250);
#             });
#
#             function onLoad() {
#                 if (window.innerWidth >= 768) {
#                     footerItems.forEach(function (item) {
#                         item.setAttribute('tabindex', '-1');
#                     });
#                 }
#                 window.removeEventListener('load', onLoad);
#             }
#
#             window.addEventListener('load', onLoad);
#
#         })();
#     </script>
# <div id="scrollbarWidth"></div>
# <script async="true" src="/properties/assets/sentry.d1738fac0b6b08fdb73d.js" type="text/javascript"></script>
# </body>
# </html>>

# %% [markdown]
# First encounter with the output can be quite intimidating. Let's try some backengineering - after looking at the offer online, we know that one of the key features we want to extract is the monthly price of '2,817'. I recommend quickly searching for 2,817 value to see where it can be found in the listing html.
#
# As what we are looking for will be a json format data, we should be most interested in something similar to "price":"2,817". It seems that 5th instance of '2817' looks similar - "primaryPrice":"£2,817 pcm".
#
# Scrolling a few lines up we can see that this part is hidden within a script block with type="text/javascript".

# %% [markdown]
# ## Locating json with key data

# %%
# Extracting script with "text/javascript" type
bs.findAll("script",{'type':"text/javascript"})[0]
# Out:
# <script type="text/javascript">
#     window.PAGE_MODEL = {"propertyData":{"id":"97077389","status":{"published":true,"archived":false},"text":{"description":"<p>An absolutely stunning two bedroom apartment located just off the sought after Sloane Avenue.</p> <p>This great value property comes unfurnished and consists of a spacious living room, a separate kitchen with Miele appliances, two double bedrooms and two recently refurbished bathrooms. The property also benefits from being in a very secure and well looked after development with a porter.</p> <p>The property is equidistant between South Kensington and Sloane Square underground stations. </p>","propertyPhrase":"2 bedroom flat","disclaimer":"<b>Disclaimer</b> - Property reference 13632. The information displayed about this property comprises a property advertisement. Rightmove.co.uk makes no warranty as to the accuracy or completeness of the advertisement or any linked or associated information, and Rightmove has no control over the content. This property advertisement does not constitute property particulars. The information is provided and maintained by <b>Draker Lettings , Sloane Square</b>. Please contact the selling agent or developer directly to obtain any information which may be available under the terms of The Energy Performance of Buildings (Certificates and Inspections) (England and Wales) Regulations 2007 or the Home Report if in relation to a residential property in Scotland.","shareText":"Check out this 2 bedroom flat for rent on Rightmove","shareDescription":"2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3 £2,817 pcm. Marketed by Draker Lettings , Sloane Square","pageTitle":"2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3"},"prices":{"primaryPrice":"£2,817 pcm","secondaryPrice":"£650 pw","displayPriceQualifier":"","exchangeRate":null},"address":{"displayAddress":"Whiteheads Grove, Chelsea, SW3","countryCode":"GB","outcode":"SW3"},"keyFeatures":[],"images":[{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_01_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_02_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_03_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_04_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_05_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_05_0000_max_135x100.jpg","size476x317":"https:// ...
# </script>

# %%
# Striping html elements and leaving only string content
script_text=bs.findAll("script",{'type':"text/javascript"})[0].text

# %%
script_text
# Out:
# '\n    window.PAGE_MODEL = {"propertyData":{"id":"97077389","status":{"published":true,"archived":false},"text":{"description":"<p>An absolutely stunning two bedroom apartment located just off the sought after Sloane Avenue.</p> <p>This great value property comes unfurnished and consists of a spacious living room, a separate kitchen with Miele appliances, two double bedrooms and two recently refurbished bathrooms. The property also benefits from being in a very secure and well looked after development with a porter.</p> <p>The property is equidistant between South Kensington and Sloane Square underground stations.\xa0</p>","propertyPhrase":"2 bedroom flat","disclaimer":"<b>Disclaimer</b> - Property reference 13632. The information displayed about this property comprises a property advertisement. Rightmove.co.uk makes no warranty as to the accuracy or completeness of the advertisement or any linked or associated information, and Rightmove has no control over the content. This property advertisement does not constitute property particulars. The information is provided and maintained by <b>Draker Lettings , Sloane Square</b>.\xa0Please contact the selling agent or developer directly to obtain any information which may be available under the terms of The Energy Performance of Buildings (Certificates and Inspections) (England and Wales) Regulations 2007 or the Home Report if in relation to a residential property in Scotland.","shareText":"Check out this 2 bedroom flat for rent on Rightmove","shareDescription":"2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3 £2,817 pcm. Marketed by Draker Lettings , Sloane Square","pageTitle":"2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3"},"prices":{"primaryPrice":"£2,817 pcm","secondaryPrice":"£650 pw","displayPriceQualifier":"","exchangeRate":null},"address":{"displayAddress":"Whiteheads Grove, Chelsea, SW3","countryCode":"GB","outcode":"SW3"},"keyFeatures":[],"images":[{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_01_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_02_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_03_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_04_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_135x100.jpg","size476x317":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_476x317.jpg","size656x437":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_656x437.jpg"}},{"url":"https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_05_0000.jpg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_05_0000_max_135x100.jpg","size476x317": ...

# %% [markdown]
# Analyzing the "script_text" above, we can see that everything after 'window.PAGE_MODEL =' has a form of a dictionary, which hints that there is a big chance that this is the json data we are looking for.

# %%
# Use regex to extract json data from the script text
script_json=re.findall(("(?<=window.PAGE_MODEL = )(?s)(.*$)"), script_text)[0]

# %%
# Transforming json data within string into dictionary
json_dict=json.loads(script_json)

# %%
# We managed to succesfully extract json data into a Python dict
type(json_dict)
# Out:
# dict

# %%
json_dict.keys()
# Out:
# dict_keys(['propertyData', 'renderProperties', 'isAuthenticated', 'analyticsInfo'])

# %%
def extract_listing_json(listing_url):
    page = requests.get(listing_url)
    bs = BeautifulSoup(page.text, 'lxml')
    
    js_script_text=bs.findAll("script",{'type':"text/javascript"})[0].text
    script_json=re.findall(("(?<=window.PAGE_MODEL = )(?s)(.*$)"),js_script_text)[0]
    json_data=json.loads(script_json)
    
    return(json_data)

# %%
listing_json=extract_listing_json(listing_url)
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Flags not at the start of the expression '(?<=window.PAGE_MODE' (truncated)

# %% [markdown]
# ## Extracting key data from listing json

# %% [markdown]
# Let's analyze the content of the listing_json to see what data we can extract. For this part of tutorial we will only focus on 'propertyData' key of the dictionary as it has the most interesting data.

# %%
listing_json.keys()
# Out:
# dict_keys(['propertyData', 'renderProperties', 'isAuthenticated', 'analyticsInfo'])

# %%
listing_json["propertyData"].keys()
# Out:
# dict_keys(['id', 'status', 'text', 'prices', 'address', 'keyFeatures', 'images', 'floorplans', 'virtualTours', 'customer', 'industryAffiliations', 'rooms', 'location', 'streetView', 'nearestAirports', 'nearestStations', 'showSchoolInfo', 'countryGuide', 'channel', 'propertyUrls', 'sizings', 'brochures', 'epcGraphs', 'bedrooms', 'bathrooms', 'transactionType', 'tags', 'misInfo', 'dfpAdInfo', 'staticMapImgUrls', 'listingHistory', 'feesApply', 'broadband', 'contactInfo', 'lettings', 'infoReelItems'])

# %%
listing_json['propertyData']
# Out:
# {'id': '97077389',
#  'status': {'published': True, 'archived': False},
#  'text': {'description': '<p>An absolutely stunning two bedroom apartment located just off the sought after Sloane Avenue.</p> <p>This great value property comes unfurnished and consists of a spacious living room, a separate kitchen with Miele appliances, two double bedrooms and two recently refurbished bathrooms. The property also benefits from being in a very secure and well looked after development with a porter.</p> <p>The property is equidistant between South Kensington and Sloane Square underground stations.\xa0</p>',
#   'propertyPhrase': '2 bedroom flat',
#   'disclaimer': '<b>Disclaimer</b> - Property reference 13632. The information displayed about this property comprises a property advertisement. Rightmove.co.uk makes no warranty as to the accuracy or completeness of the advertisement or any linked or associated information, and Rightmove has no control over the content. This property advertisement does not constitute property particulars. The information is provided and maintained by <b>Draker Lettings , Sloane Square</b>.\xa0Please contact the selling agent or developer directly to obtain any information which may be available under the terms of The Energy Performance of Buildings (Certificates and Inspections) (England and Wales) Regulations 2007 or the Home Report if in relation to a residential property in Scotland.',
#   'shareText': 'Check out this 2 bedroom flat for rent on Rightmove',
#   'shareDescription': '2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3 £2,817 pcm. Marketed by Draker Lettings , Sloane Square',
#   'pageTitle': '2 bedroom flat for rent in Whiteheads Grove, Chelsea, SW3'},
#  'prices': {'primaryPrice': '£2,817 pcm',
#   'secondaryPrice': '£650 pw',
#   'displayPriceQualifier': '',
#   'exchangeRate': None},
#  'address': {'displayAddress': 'Whiteheads Grove, Chelsea, SW3',
#   'countryCode': 'GB',
#   'outcode': 'SW3'},
#  'keyFeatures': [],
#  'images': [{'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_01_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_01_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_02_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_02_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_03_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_03_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_04_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_04_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_05_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_05_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_05_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_05_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_06_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_06_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_06_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_06_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_07_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_07_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_07_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_07_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_08_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_08_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_08_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_08_0000_max_656x437.jpg'}},
#   {'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_IMG_09_0000.jpg',
#    'caption': None,
#    'resizedImageUrls': {'size135x100': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_09_0000_max_135x100.jpg',
#     'size476x317': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_09_0000_max_476x317.jpg',
#     'size656x437': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_IMG_09_0000_max_656x437.jpg'}}],
#  'floorplans': [{'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_FLP_01_0000.jpg',
#    'caption': 'Floorplan 1',
#    'type': 'IMAGE',
#    'resizedFloorplanUrls': {'size296x197': 'https://media.rightmove.co.uk/dir/52k/51411/97077389/51411_13632_FLP_01_0000_max_296x197.jpg'}}],
#  'virtualTours': [],
#  'customer': {'branchDisplayName': 'Draker Lettings , Sloane Square',
#   'displayAddress': '1 Holbein Place,\r\nLondon,\r\nSW1W 8NS',
#   'logoPath': 'https://media.rightmove.co.uk/52k/51411/branch_logo_51411_0001.jpeg',
#   'description': ["Having identified the opportunity for an estate agency specialising in lettings only - an agency that's driven by exceptional service and results - we opened Draker's doors for the first time in July 2010.",
#    "Based in our spacious 2,000 sq ft office in Sloane Square, we let well over 400 properties every year. In fact, we've achieved a consistent annual growth of more than 40% since setting up shop.",
#    "Experts in property, we're fundamentally all about people. Ours are key to Draker's success, so we make sure everyone's both trained and rewarded accordingly. We all work to a fundamental set of values encompassing continual, incremental improvement; integrity at all times; and total accountability to every customer and client. We're aware that our industry isn't perfect, so we go above and beyond the call of duty to promote trust and respect - both internally and externally.",
#    "Our extensive property list comprises high quality rentals in Chelsea, Knightsbridge, Belgravia, Pimlico and Fulham and the surrounding areas. We focus exclusively on lettings because it's what we know best, it's what we do best and we think that we do it better than the rest.",
#    "We make a point of being friendly and easy to deal with, but you won't find a more determined, dynamic and results-driven bunch on our patch.",
#    "We keep the whole process focused and straightforward - and we keep it moving. That means calling you back quickly, being available when it suits you, making sure you understand everything and giving helpful advice if it's needed.",
#    'For lettings with fewer headaches, just get in touch.',
#    "Draker Lettings are a member of The Property Ombudsman (www.tpos.co.uk), The UK Association of Letting Agents(www.ukala.org.uk) and operate a full client monies protection scheme - which means that all client funds are protected at all times. We're also members of the government authorized My Deposits protection scheme (www.mydeposits.co.uk), ensuring that all tenants' deposits are handled correctly to give both tenants and landlords peace of mind."],
#   'bannerAd': 'https://media.rightmove.co.uk/52k/51411/1510756368868_bp_pd_h.jpg',
#   'mpuAd': 'https://media.rightmove.co.uk/52k/51411/1510756377865_bp_mpu.jpg',
#   'customerProfileUrl': '/estate-agents/agent/Draker-Lettings/Sloane-Square-51411.html',
#   'customerBannerAdProfileUrl': '/estate-agents/agent/Draker-Lettings/Sloane-Square-51411.html#lam_about_us',
#   'customerPropertiesUrl': '/property-to-rent/find/Draker-Lettings/Sloane-Square.html?locationIdentifier=BRANCH%5E51411&propertyStatus=all&includeLetAgreed=true&_includeLetAgreed=on'},
#  'industryAffiliations': [],
#  'rooms': [],
#  'location': {'latitude': 51.4915,
#   'longitude': -0.166217,
#   'circleRadiusOnMap': 0,
#   'zoomLevel': 15,
#   'pinType': 'ACCURATE_POINT'},
#  'streetView': {'heading': None,
#   'pitch': None,
#   'zoom': None,
#   'latitude': 51.4915,
#   'longitude': -0.166217},
#  'nearestAirports': [],
#  'nearestStations': [{'name': 'Sloane Square Station',
#    'types': ['LONDON_UNDERGROUND'],
#    'distance': 0.42272894236062336,
#    'unit': 'miles'},
#   {'name': 'South Kensington Station',
#    'types': ['LONDON_UNDERGROUND'],
#    'distance': 0.37531718745259707,
#    'unit': 'miles'},
#   {'name': 'Knightsbridge Station',
#    'types': ['LONDON_UNDERGROUND'],
#    'distance': 0.7374990961549106,
#    'unit': 'miles'}],
#  'showSchoolInfo': True,
#  'countryGuide': None,
#  'channel': 'RES_LET',
#  'propertyUrls': {'similarPropertiesUrl': '/property-to-rent/SW3-3HG.html?radius=0.5&minPrice=2500&maxPrice=3500&minBedrooms=2'},
#  'sizings': [],
#  'brochures': [],
#  'epcGraphs': [{'url': 'https://media.rightmove.co.uk/52k/51411/97077389/51411_13632_EPCGRAPH_01_0000.jpg',
#    'caption': 'EPC 1'}],
#  'bedrooms': 2,
#  'bathrooms': 2,
#  'transactionType': 'RENT',
#  'tags': [],
#  'misInfo': {'branchId': 51411,
#   'offerAdvertStampTypeId': None,
#   'premiumDisplay': False,
#   'premiumDisplayStampId': None,
#   'brandPlus': True,
#   'featuredProperty': True},
#  'dfpAdInfo': {'channel': 'RES_LET',
#   'targeting': [{'key': 'SO', 'value': ['FALSE']},
#    {'key': 'R', 'value': ['FALSE']},
#    {'key': 'AUCP', 'value': ['FALSE']},
#    {'key': 'CCY', 'value': ['GBP']},
#    {'key': 'UTo_C', 'value': ['GB']},
#    {'key': 'CT', 'value': ['property-to-rent']},
#    {'key': 'TT', 'value': ['rent']},
#    {'key': 'BD', 'value': ['2']},
#    {'key': 'PT', 'value': ['flats_apartments']},
#    {'key': 'PST', 'value': ['flat']},
#    {'key': 'RESALEPRICE', 'value': ['2817']},
#    {'key': 'B', 'value': ['Band9']},
#    {'key': 'B_ID', 'value': ['51411']},
#    {'key': 'C_ID', 'value': ['Draker Lettings ']},
#    {'key': 'FP', 'value': ['Y']},
#    {'key': 'EPC', 'value': ['Y']},
#    {'key': 'P_ID', 'value': ['97077389']},
#    {'key': 'OV', 'value': ['N']},
#    {'key': 'UTo_D', 'value': ['SW3']},
#    {'key': 'UTo_Inc', 'value': ['3HG']},
#    {'key': 'FS', 'value': ['unfurnished']},
#    {'key': 'UTo_UKZ', 'value': ['England']}]},
#  'staticMapImgUrls': {'staticMapImgUrlMobile': 'https://media.rightmove.co.uk/map/_generate?width=375&height=375&zoomLevel=15&latitude=51.4915&longitude=-0.166217&signature=kXHWGXJdSDFo5fbhpjmTOMP-0eI=',
#   'staticMapImgUrlTablet': 'https://media.rightmove.co.uk/map/_generate?width=768&height=347&zoomLevel=15&latitude=51.4915&longitude=-0.166217&signature=9vKe25wzPoaqxJAWUDaVJ0yr5As=',
#   'staticMapImgUrlDesktopSmall': 'https://media.rightmove.co.uk/map/_generate?width=580&height=347&zoomLevel=15&latitude=51.4915&longitude=-0.166217&signature=g-hp0dBnZl9B81NSbePF40Hr_1k=',
#   'staticMapImgUrlDesktopLarge': 'https://media.rightmove.co.uk/map/_generate?width=761&height=347&zoomLevel=15&latitude=51.4915&longitude=-0.166217&signature=_TG5Hy3qe-T2J0hOvYHGcPfQ-No='},
#  'listingHistory': {'listingUpdateReason': 'Added on 09/09/2020'},
#  'feesApply': {'feesApplyText': '<h2>Relevant letting fees and tenant protection information</h2><p>In addition to paying rent for the property, you may also be required to make the following permitted payments:<br /><b><br />Before the tenancy starts: </b></p><ul><li>Holding Deposit: 1 week s rent; and/or</li><li>Deposit: 5 weeks rent (or in the case of rental income of more than £50,000 per annum 6 weeks rent).</li></ul><p><b>During the tenancy:</b></p><ul><li>Payments to other third parties: such as Council Tax, utilities or payments for communications services;</li><li>Default Charges: such as payments for the replacement of lost keys or interest on overdue rent; and   </li><li>Tenancy Transaction Charges: such as requests to vary or assign the tenancy.</li></ul><p><b>Tenant Protection</b></p><p>Draker Lettings is a member of UK ALA, which is a client money protection scheme, and a member of The Property Ombudsman, which is a redress scheme. You can find out more details on the agent s website or by contacting the agent directly.</p>',
#   'feesApplyTitle': 'Tenancy information',
#   'feesApplyDisclaimer': "<div>Please note that lettings agents are required by law to publish on their websites information for potential tenants about relevant fees, redress schemes and client money protection schemes (including the names of those schemes). Relevant fees must also be published on third party websites, such as Rightmove. For properties to rent in England and Wales, details of the agent's membership of any redress scheme and client money protection scheme must also be published with their fees on Rightmove. It is the agent's responsibility to ensure that all relevant information is provided to Rightmove and is up to date and accurate. If the relevant information does not appear here, the agent may have included it within the property description.</div>"},
#  'broadband': {'disclaimer': "* Average speeds are based on the download speeds of at least 50% of customers at peak time (8pm to 10pm) from packages available on comparethemarket.com. Speed can be affected by a range of technical and environmental factors. The speed you receive where you live may be lower than that listed above. You can check the estimated speed to your property prior to purchasing. Fibre/cable services at your postcode are subject to availability. You can confirm availability on the provider's website. Providers may increase charges. You should have the right to exit your contract without penalty if this happens. The information is provided and maintained by <b>Decision Technologies Limited</b>.",
#   'broadbandCheckerUrl': 'https://partnerships-broadband.comparethemarket.com/v1/broadband/rightmove/SW33HG?apikey=11273f2ea3272bf1e97867ca995302419dc60e178fb4708e849a6803cdae7552'},
#  'contactInfo': {'contactMethod': 'EMAIL',
#   'telephoneNumbers': {'localNumber': '020 8012 4447',
#    'internationalNumber': None,
#    'disclaimerText': 'Local call rate',
#    'disclaimerTitle': 'How much will it cost me to call the number displayed on the site?',
#    'disclaimerDescription': "Standard geographic charges from landlines and mobiles apply and calls may be included in your telecom provider's call package."}},
#  'lettings': {'letAvailableDate': '15/10/2020',
#   'deposit': None,
#   'letType': 'Long term',
#   'furnishType': 'Unfurnished'},
#  'infoReelItems': [{'title': 'PROPERTY TYPE',
#    'type': 'PROPERTY_TYPE',
#    'primaryText': 'Flat',
#    'secondaryText': ''},
#   {'title': 'BEDROOMS',
#    'type': 'BEDROOMS',
#    'primaryText': 'x2',
#    'secondaryText': ''},
#   {'title': 'BATHROOMS',
#    'type': 'BATHROOMS',
#    'primaryText': 'x2',
#    'secondaryText': ''}]}

# %%
listing_json['propertyData']["id"]
# Out:
# '68374505'

# %%
listing_json['propertyData']["prices"]
# Out:
# {'primaryPrice': '£1,000 pcm',
#  'secondaryPrice': '£231 pw',
#  'displayPriceQualifier': '',
#  'exchangeRate': None}

# %%
listing_json['propertyData']["keyFeatures"]
# Out:
# []

# %%
listing_json['propertyData']["location"]
# Out:
# {'latitude': 51.62912,
#  'longitude': -0.12552,
#  'circleRadiusOnMap': 0,
#  'zoomLevel': 15,
#  'pinType': 'APPROXIMATE_POINT'}

# %%
listing_json['propertyData']["lettings"]
# Out:
# {'letAvailableDate': None,
#  'deposit': None,
#  'letType': 'Long term',
#  'furnishType': None}

# %%
listing_json['propertyData']["bedrooms"]
# Out:
# 2

# %%
listing_json['propertyData']["bathrooms"]
# Out:
# 2

# %%
listing_json['propertyData']["sizings"]
# Out:
# []

# %%
# We will focus on extracting data stored within these keys for each listing
main_data_keys=['prices','address','rooms','bedrooms','bathrooms','location']

# %%
def extract_listing_data(listing_json):
    data_json={}
    
    #First extract the listing id
    try:
        data_json["id"]=listing_json['propertyData']["id"]
    except:
        pass
    for k in main_data_keys:
        
        #If a key contains a subdictionary, then extract all the key:value pairs
        if type(listing_json['propertyData'][k])==dict:
            for k2 in listing_json['propertyData'][k].keys():
                try:
                    data_point=listing_json['propertyData'][k][k2]
                    data_json[k2]=(data_point)
                except:
                    continue
                    
        #If the base key value is not a dictionary, extract the value
        else:
            data_json[k]=(listing_json['propertyData'][k])
    
    #As 'sizings' key has more layers of subdictionaries, we will focus only on 2 values 
    try:
        data_json["property_size"]=listing_json['propertyData']["sizings"][0]['minimumSize']
        data_json["area_unit"]=listing_json['propertyData']["sizings"][0]['unit']
    except:
        pass
    return(data_json)

# %%
# Output from a single listing
extract_listing_data(listing_json)
# Out:
# {'id': '72742005',
#  'primaryPrice': '£1,000 pcm',
#  'secondaryPrice': '£231 pw',
#  'displayPriceQualifier': '',
#  'exchangeRate': None,
#  'displayAddress': 'Brockley Road, London, SE4',
#  'countryCode': 'GB',
#  'outcode': 'SE4',
#  'rooms': [],
#  'bedrooms': 1,
#  'bathrooms': 1,
#  'latitude': 51.455734,
#  'longitude': -0.03676,
#  'circleRadiusOnMap': 0,
#  'zoomLevel': 15,
#  'pinType': 'ACCURATE_POINT'}

# %% [markdown]
# # Extracting multiple offers from page

# %% [markdown]
# After having successfully extracted data from a single listing, we need to go up in page hierarchy and conduct two steps, which will allow us to extract data from multiple offers:
#  - Get list of all listings from first page extracting the appropriate href
#  - Iterate through multiple pages and repeat step from previous bullet

# %% [markdown]
# ## Locating listing href

# %%
# Let's start from first page - this is also where you want to apply all the filters and sorting options
first_page_url='https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&minPrice=1000&sortType=1&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords='

# %%
requests.get(first_page_url)
# Out:
# <Response [200]>

# %%
page = requests.get(first_page_url)
bs = BeautifulSoup(page.text, 'lxml')
bs.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="is-not-modern property-to-rent channel-based-property-types channel--rent" lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <title>Properties To Rent in London | Rightmove</title>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, shrink-to-fit=no, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="Flats &amp; Houses To Rent in London - Find properties with Rightmove - the UK's largest selection of properties." name="description"/>
# <meta content="origin-when-cross-origin" name="referrer"/><link crossorigin="" href="https://media.rightmove.co.uk:443" rel="preconnect"/>
# <link crossorigin="" href="//product.rightmove.co.uk" rel="preconnect"/><link href="/pvw/images/favicons/rebranded/favicon.ico" rel="shortcut icon"/><link href="/pvw/images/favicons/rebranded/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/pvw/images/favicons/rebranded/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/pvw/images/favicons/rebranded/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/pvw/images/favicons/rebranded/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/pvw/images/favicons/rebranded/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><meta content="#262637" name="msapplication-TileColor"/>
# <meta content="/pvw/images/favicons/rebranded/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="/pvw/images/favicons/rebranded/browserconfig.xml" name="msapplication-config"/><link href="/pvw/images/favicons/rebranded/manifest.json" rel="manifest"/>
# <script>var RESOURCE_PREFIX = '';</script>
# <meta content="Rightmove" name="apple-mobile-web-app-title"/>
# <meta content="Rightmove" name="application-name"/>
# <meta content="#262637" name="theme-color"/><meta content="/" property="og:url"/>
# <meta content="Rightmove.co.uk" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="/pvw/images/favicons/rebranded/logo-share-fb.png" property="og:image"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="Rightmove.co.uk" property="og:site_name"/>
# <meta content="Search over a Million properties for sale and to rent from the top estate agents and developers in the UK" property="og:description"/>
# <meta content="rightmove.plc" property="fb:admins"/>
# <meta content="485764298115191" property="fb:app_id"/>
# <meta content="2911111" property="twitter:account_id"/>
# <link href="https://www.rightmove.co.uk/property-to-rent/London-87490.html" rel="canonical"/>
# <!--[if (lte IE 9)&(!IEMobile)]>
#     <script src="/pvw/javascript/oldie.e9a5a594dce4be47d9c0.js"></script>
#     <![endif]-->
# <!--[if (IE 8)&(!IEMobile)]>
#     <script>window.isIE8 = true;</script>
#     <![endif]-->
# <!--[if (IE 9)&(!IEMobile)]>
#     <script>window.isIE9 = true;</script>
#     <![endif]--><style type="text/css">
#         svg {
#             display: none;
#         }
#     </style>
# <style type="text/css">
#     @font-face {
#         font-family: 'effra-medium';
#         src: url('/ps/fonts/effra/Effra_WLatn_Md.eot'); /* IE9 Compat Modes */
#         src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Md.eot?#iefix') format('embedded-opentype'),
#             /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff2') format('woff2'),
#             /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff') format('woff');
#         font-style: normal;
#     }
#
#     @font-face {
#         font-family: 'effra-regular';
#         src: url('/ps/fonts/effra/Effra_WLatn_Rg.eot');
#         src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Rg.eot?#iefix') format('embedded-opentype'),
#             /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff2') format('woff'),
#             /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff') format('woff');
#         font-style: normal;
#     }
# </style>
# <link href="/pvw/css/rebranded-font.search.head.0225d69aeefcdaecca7a.css" rel="stylesheet"/>
# <link href="/pvw/css/rebranded-font.search.build.1cfa4d3f1f814d899663.css" media="spoderman" rel="stylesheet"/>
# <!--[if (lte IE 9)&(!IEMobile)]>
#     <link rel="stylesheet" href="/pvw/css/rebranded-font.search.build.oldie.b6a987b11ae358b746f1.css">
# <![endif]-->
# <script>!function(n){var r={};function o(e){if(r[e])return r[e].exports;var t=r[e]={i:e,l:!1,exports:{}};return n[e].call(t.exports,t,t.exports,o),t.l=!0,t.exports}o.m=n,o.c=r,o.d=function(e,t,n){o.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:n})},o.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},o.t=function(t,e){if(1&e&&(t=o(t)),8&e)return t;if(4&e&&"object"==typeof t&&t&&t.__esModule)return t;var n=Object.create(null);if(o.r(n),Object.defineProperty(n,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var r in t)o.d(n,r,function(e){return t[e]}.bind(null,r));return n},o.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return o.d(t,"a",t),t},o.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},o.p="/pvw/",o(o.s=1033)}({1033:function(e,t,n){"use strict";var r=document.getElementsByTagName("link"),o=window.document.styleSheets;function u(e){for(var t=0,n=o.length;t<n;t++){var r=o[t];if(r.href&&-1<r.href.indexOf(e.href))return e.media="all",!0}setTimeout(u,null,e)}!function(){for(var e=0,t=r.length;e<t;e++)"spoderman"===r[e].getAttribute("media")&&u(r[e])}()}});
# </script>
# <!-- Other tags... -->
# <link as="font" crossorigin="" href="/ps/fonts/effra/Effra_WLatn_Md.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="/ps/fonts/effra/Effra_WLatn_Rg.woff2" rel="preload"/>
# </head>
# <body class="header-rebranding rebranded-logo">
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-T4524Q&amp;gtm_auth=g2ndo_352oWlGwJG7HHfyw&amp;gtm_preview=env-7&amp;gtm_cookies_win=x" style="display:none;visibility:hidden" width="0">
# </iframe>
# </noscript>
# <svg height="0" style="position:absolute" width="0"><symbol id="core-icon--account-silhouette" viewbox="0 0 13.8 21.8"><circle cx="6.9" cy="5" r="5"></circle><path d="M12 13.6L8.7 12c-.5-.2-1.2-.4-1.8-.4s-1.3.2-1.8.4l-3.3 1.6c-1 .5-1.8 1.8-1.8 2.9v3.3c0 1.1.9 2 2 2h9.8c1.1 0 2-.9 2-2v-3.3c0-1.1-.8-2.4-1.8-2.9z"></path></symbol><symbol id="core-icon--awaiting-image" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="
viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M14 8v5a1 1 0 01-1 1H7v1h6a2 2 0 002-2V3a2 2 0 00-2-2H3a2 2 0 00-2 2v10a2 2 0 002 2h2v-1H3a1 1 0 01-1-1v-2h7v-1H2V3a1 1 0 011-1h2v5h1V2h7a1 1 0 011 1v4H9v1h5z"></path></symbol><symbol clip-rule="evenodd" fill-rule="evenodd" id="core-icon--rightmove-icon-logo" stroke-linejoin="round" stroke-miterlimit="1.414" viewbox="0 0 2099 2138" xmlns="http://www.w3.org/2000/svg"><path d="M1879.272 2137.031h-416.317l-413.787-350.321-415.426 350.321H218.604c-58.45 0-113.366-22.77-154.683-64.154-41.317-41.35-63.983-96.363-63.92-154.813l1.145-935.638c.062-57.7 22.346-112.154 62.713-153.404l8.975-8.325L1049.134 0l985.539 829.247c40.237 41.091 62.416 95.379 62.45 152.883l1.15 935.542c.095 58.517-22.642 113.626-64.025 155.076-41.384 41.445-96.425 64.283-154.976 64.283zm-323.554-253.142h289.38l-1.084-884.984-794.88-668.171-794.88 668.138-1.05 885.017H541.28l508.217-428.567 506.221 428.567z" fill="#00deb6" fill-rule="nonzero"></path></symbol><symbol clip-rule="evenodd" fill-rule="evenodd" id="core-icon--rightmove-wi ...
# <header class="seo-globalHeader" data-test="global-header" id="globalHeader">
# <script type="application/javascript">
#
# 			var headerLogic = {
#
# 				constructor:function () {
# 					this.DATA_LAYER = 'dataLayer';
# 					this.RM_DATA_LAYER = 'rmDataLayer';
# 					this.NAV_ITEM_CLASS = 'seo-nav-item';
# 					this.NAV_ACTIVE_CLASS = 'active-nav';
# 					this.NAV_LINKS_SELECTOR = '.' + this.NAV_ITEM_CLASS + ' .seo-nav-link';
# 					this.NAV_ITEM_ACTIVE_SELECTOR = '.' + this.NAV_ITEM_CLASS + '.' + this.NAV_ACTIVE_CLASS;
# 					this.NAV_DATA_IDENTIFIER = 'data-nav';
#                     this.HOME_LOGO_SELECTOR = '.seo-logo';
#
# 					this.SUBNAV_BACKGROUND_CLASS = 'seo-nav-subNav-background';
# 					this.SUBNAV_LINKS_SELECTOR = '.seo-nav-subNav-link';
# 					this.SUBNAV_MOB_LINKS_SELECTOR = '.seo-mob-nav-link';
# 					this.SUBNAV_DATA_PARENT_IDENTIFIER = 'data-parent-nav';
# 					this.NAV_BACKGROUND_CLASS = 'seo-nav-backdrop';
#
# 					this.USER_ACCOUNT_SELECTOR = '.seo-nav-item-user';
# 					this.USER_MOBILE_ACCOUNT_SELECTOR = '#seo-mob-nav-user';
#
# 					this.USER_LOGIN_SELECTOR = '#seo-nav-login-link';
#                     this.USER_MOBILE_LOGIN_SELECTOR = '#seo-mob-nav-sign-in';
#
# 					this.HEADER = 'header';
#
# 					this.MOBILE_ACTION_BUTTON = 'seo-mob-nav-display-action';
# 					this.MOBILE_MODAL_BACKGROUND = 'seo-mob-nav-modal-background';
# 					this.MOBILE_MODAL_CONTENT = 'seo-mob-nav-modal-content';
# 					this.MOBILE_CLOSE_ACTION_BUTTON = 'close-button';
# 				},
#
# 				init:function () {
# 					this.checkUserAuth();
# 					this.bindEvents();
# 				},
#
# 				bindEvents:function () {
# 					const navLinks = this.qsAll(this.NAV_LINKS_SELECTOR);
# 					const navBackdrop = this.qs('.' + this.NAV_BACKGROUND_CLASS);
# 					navBackdrop.addEventListener('click', function() {
# 						this.removeNavigation();
# 				    }.bind(this));
#
# 					for (let i = 0; i < navLinks.length; i++) {
# 						navLinks[i].addEventListener('click', function(event) {
# 							event.preventDefault();
#                             this.manageActiveNav(event);
#                         }.bind(this));
# 					}
#
#                     const homepageLinks = this.qsAll(this.HOME_LOGO_SELECTOR);
#                     for (let j = 0; j < homepageLinks.length; j++) {
#                         homepageLinks[j].addEventListener('click', function(event) {
#                             this.trackNavigation(this.navigationActions().NAVIGATED, "homepage", this.HEADER, "", event.currentTarget.href);
#                         }.bind(this));
#                     }
#
# 					const subNavLinks = this.qsAll(this.SUBNAV_LINKS_SELECTOR);
# 					for (let j = 0; j < subNavLinks.length; j++) {
# 						subNavLinks[j].addEventListener('click', function(event) {
# 							let elementText = event.target.text.toLowerCase();
# 						    this.trackNavigation(this.navigationActions().NAVIGATED, elementText, this.HEADER, event.target.getAttribute(this.SUBNAV_DATA_PARENT_IDENTIFIER), event.currentTarget.href);
# 					    }.bind(this));
# 					}
#
# 					const subMobNavLinks = this.qsAll(this.SUBNAV_MOB_LINKS_SELECTOR);
# 					for (let j = 0; j < subMobNavLinks.length; j++) {
# 						subMobNavLinks[j].addEventListener('click', function(event) {
# 							let elementText = event.target.text.toLowerCase();
# 						    this.trackNavigation(this.navigationActions().NAVIGATED, elementText, this.HEADER, event.target.getAttribute(this.SUBNAV_DATA_PARENT_IDENTIFIER), event.currentTarget.href);
# 					    }.bind(this));
# 					}
#
# 					const accountLinks = this.qs(this.USER_ACCOUNT_SELECTOR).children;
# 					for (let k = 0; k < accountLinks.length; k++) {
# 						accountLinks[k].addEventListener('click', function(event) {
# 							let elementText = event.currentTarget.text.trim().toLowerCase();
# 						this.trackNavigation(this.navigationActions().NAVIGATED, elementText, this.HEADER, elementText, event.currentTarget.href);
# 					}.bind(this));
# 					}
#
# 					const mobileActionButton = this.qs('.'+ this.MOBILE_ACTION_BUTTON);
# 					mobileActionButton.addEventListener('click', function() {
# 						this.openSeoNav();
# 				    }.bind(this));
#
# 					const mobileCloseActionButton = this.qs('.'+ this.MOBILE_CLOSE_ACTION_BUTTON);
# 					mobileCloseActionButton.addEventListener('click', function() {
# 						this.closeSeoNav();
# 				    }.bind(this));
#
# 					const mobileModalBackground = this.qs('#'+ this.MOBILE_MODAL_BACKGROUND);
# 					mobileModalBackground.addEventListener('click', function() {
# 						this.closeSeoNav();
# 				    }.bind(this));
# 				},
#
# 				checkUserAuth:function () {
# 					if (this.getCookie('sso2')) {
# 						const userAccountElement = this.qs(this.USER_ACCOUNT_SELECTOR);
# 						this.addClass(userAccountElement, 'authed');
#
# 						const userMobileAccountElement = this.qs(this.USER_MOBILE_ACCOUNT_SELECTOR);
# 						this.addClass(userMobileAccountElement, 'authed');
# 					} else {
#                          const loginElement = this.qs(this.USER_LOGIN_SELECTOR);
#                          loginElement.href = this.getLoginLink();
#                          const loginMobileElement = this.qs(this.USER_MOBILE_LOGIN_SELECTOR);
#                          loginMobileElement.href = this.getLoginLink();
#                      }
# 				},
#
# 				getCookie:function (cname) {
# 					var name = cname + "=";
# 					var decodedCookie = decodeURIComponent(document.cookie);
# 					var ca = decodedCookie.split(';');
# 					for(var i = 0; i < ca.length; i++) {
# 						var c = ca[i];
# 						while (c.charAt(0) == ' ') {
# 							c = c.substring(1);
# 						}
# 						if (c.indexOf(name) == 0) {
# 							return c.substring(name.length, c.length);
# 						}
# 					}
# 					return "";
# 				},
#
# 				manageActiveNav:function (event) {
# 					const elClass = event.target.getAttribute(this.NAV_DATA_IDENTIFIER);
# 					const elementClick = '.' + this.NAV_ITEM_CLASS + '.' + elClass;
#
# 					this.toggleClass(elementClick, this.NAV_ACTIVE_CLASS);
# 					this.removeExistingActiveNav(elClass);
# 					this.manageBackDrops();
#
# 					const element = this.qs(elementClick);
# 					if (element && element.classList.contains(this.NAV_ACTIVE_CLASS)) {
# 						const elementText = event.target.text.toLowerCase();
# 						this.trackNavigation(this.navigationActions(elementText).OPENED, elementText, this.HEADER, elementText, undefined);
# 					}
# 				},
#
# 				removeExistingActiveNav:function (elClass) {
# 					const existingActives = this.qsAll(this.NAV_ITEM_ACTIVE_SELECTOR);
# 					if (existingActives.length > 1) {
# 						for (let i = 0; i < existingActives.length; i++) {
# 							if (existingActives[i].className.indexOf(elClass) === -1) {
# 								existingActives[i].className = existingActives[i].className.replace(/\bactive-nav\b/g, '');
# 							}
# 						}
# 					}
# 					if (existingActives.length === 0) {
# 						const elementText = elClass.replace('-', ' ');
# 						this.trackNavigation(this.navigationActions(elementText).CLOSED, elementText, this.HEADER, elementText, undefined);
# 					}
# 				},
#
# 				removeNavigation:function () {
# 					const existingActives = this.qsAll(this.NAV_ITEM_ACTIVE_SELECTOR);
# 					for (let i = 0; i < existingActives.length; i++) {
# 						existingActives[i].className = existingActives[i].className.replace(/\bactive-nav\b/g, '');
# 						const elementText = existingActives[i].children[0].getAttribute(this.NAV_DATA_IDENTIFIER).replace('-', ' ');
# 						this.trackNavigation(this.navigationActions(elementText).CLOSED, undefined, this.HEADER, elementText, undefined);
# 					}
#
# 					this.manageBackDrops();
# 				},
#
# 				manageBackDrops:function () {
# 					const navBackdrop = this.qs('.' + this.NAV_BACKGROUND_CLASS);
# 					const subNavBackground = this.qs('.' + this.SUBNAV_BACKGROUND_CLASS);
# 					const navActive = this.qsAll(this.NAV_ITEM_ACTIVE_SELECTOR).length > 0;
#
# 					if (navActive) {
# 						if (!this.qs('.seo-nav-backdrop--open')) {
# 							this.addClass(navBackdrop, 'seo-nav-backdrop--open');
# 							this.addClass(subNavBackground, 'seo-nav-subNav-background--open');
# 						}
# 					} else {
# 						this.removeClass(navBackdrop, 'seo-nav-backdrop--open');
# 						this.removeClass(subNavBackground, 'seo-nav-subNav-background--open');
# 					}
# 				},
#
# 				openSeoNav:function () {
# 					var content = document.getElementById(this.MOBILE_MODAL_CONTENT);
# 					content.style.width = '270px';
#
# 					var background = document.getElementById(this.MOBILE_MODAL_BACKGROUND);
# 					background.style.width = '100%';
# 					background.style.opacity = '1';
#
# 					var tabbables = document.getElementsByClassName('seo-link');
# 					for (var i = 0; i < tabbables.length; i++) {
# 						tabbables[i].tabIndex = 0;
# 					}
#
# 					var body = document.getElementsByTagName('body');
# 					body[0].style.overflowY = 'hidden';
# 				},
#
# 				closeSeoNav:function () {
# 					var content = document.getElementById(this.MOBILE_MODAL_CONTENT);
# 					content.style.width = '0';
#
# 					var background = document.getElementById(this.MOBILE_MODAL_BACKGROUND);
# 					background.style.opacity = '0';
# 					background.style.width = '0';
#
# 					var tabbables = document.getElementsByClassName('seo-link');
# 					for (var i = 0; i < tabbables.length; i++) {
# 						tabbables[i].tabIndex = -1;
# 					}
#
# 					var body = document.getElementsByTagName('body');
# 					body[0].style.overflowY = 'auto';
# 				},
#
# 				trackNavigation:function (action, label, module, menu, url) {
# 					this.trackData({
# 						event: 'navigation',
# 						gaEventData: {
# 							action: action,
# 							label: label,
# 							menu: menu ? menu.replace('-', ' ') : undefined,
# 							module: module,
# 							destinationUrl: url ? url.split('?')[0] : undefined //strip out query string
# 						}
# 					});
# 				},
#
# 				navigationActions:function (value) {
# 					return {
# 						NAVIGATED: 'navigated to',
# 						OPENED: 'opened ' + value + ' nav',
# 						CLOSED: 'closed ' + value + ' nav'
# 					};
# 				},
#
# 				trackData:function (data) {
# 					window[this.DATA_LAYER] && window[this.DATA_LAYER].push(data);
# 					window[this.RM_DATA_LAYER] && window[this.RM_DATA_LAYER].push(data);
# 				},
#
# 				qs:function (selector) {
# 					return document.querySelector(selector);
# 				},
#
# 				qsAll:function (selector) {
# 					return document.querySelectorAll(selector);
# 				},
#
# 				removeClass:function (element, className) {
# 					const exp = '\\b' + className + '\\b';
# 					const rx = new RegExp(exp, 'g');
#
# 					element.className = element.className.replace(rx, '');
# 				},
#
# 				addClass:function (element, className) {
# 					const arr = element.className.split(' ');
#
# 					if (arr.indexOf(className) === -1) {
# 						element.className += ' ' + className;
# 					}
# 				},
#
# 				toggleClass:function (elClass, activeClass) {
# 					const element = this.qs(elClass);
#
# 					if (element.classList) {
# 						element.classList.toggle(activeClass);
# 					} else {
# 						// For IE9
# 						const classes = element.className.split(' ');
# 						const i = classes.indexOf(activeClass);
#
# 						if (i >= 0) {
# 							classes.splice(i, 1);
# 						} else {
# 							classes.push(activeClass);
# 							element.className = classes.join(' ');
# 						}
# 					}
# 				},
# 				getLoginLink: function() {
#                     if (window.location.href) {
#                         return "/login.html?from=" + window.location.href;
#                     }
#                     return "/login.html"
#                 }
# 			};
#
# 			window.addEventListener('DOMContentLoaded', function(){
# 				headerLogic.constructor();
# 				headerLogic.init();
# 			});
#
# 		</script>
# <noscript>
# <div class="seo-globalHeader-noJavascript"><b>!</b> It appears that Javascript is disabled on your browser.
# 				We're sorry, some parts of the Rightmove website don't work at their best without JavaScript enabled.
# 				Please ensure your JavaScript is turned on to make sure you have the best experience.</div>
# </noscript>
# <!--[if (lte IE 8)&(!IEMobile)]>
# 		<div class="seo-globalHeader-oldBrowser">
# 			<p>You appear to be using a very old browser that doesn’t allow our site to work properly.</p>
# 			<p>We recommend you:</p>
# 			<ol>
# 				<li>Update your browser</li>
# 				<li>Use another up-to-date browser such as Chrome, Firefox or Safari.</li>
# 			</ol>
# 		</div>
# 		<![endif]-->
# <div class="seo-header-container">
# <div class="seo-header">
# <a aria-label="Go to Rightmove homepage" class="seo-logo" href="/">
# <svg height="25" viewbox="0 0 118 25" width="118" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M114.114 13.262h2.022V7.088l-5.56-4.662-5.56 4.662v6.174h2.021l3.554-2.993 3.523 2.993zm2.259 1.764h-2.907l-2.89-2.441-2.907 2.441h-2.906a1.507 1.507 0 0 1-1.517-1.528l.016-6.52c0-.41.158-.788.442-1.071l.063-.063 6.809-5.718 6.887 5.78c.284.284.442.662.442 1.072l.016 6.52c0 .41-.158.788-.442 1.087-.285.3-.695.441-1.106.441z" fill="#00DEB6"></path>
# <path d="M60.185 8.631c-.695 0-1.359.126-2.006.378a4.505 4.505 0 0 0-1.627 1.071 4.517 4.517 0 0 0-.474-.504c-.19-.173-.411-.33-.68-.472a4.138 4.138 0 0 0-.884-.347c-.348-.094-.727-.126-1.153-.126-.711 0-1.327.126-1.849.394-.52.268-.963.599-1.295 1.008l-.11-1.15h-3.191V19.31h3.333v-5.607c0-.661.19-1.213.584-1.638.395-.425.9-.646 1.548-.646.569 0 .995.174 1.28.504.284.347.426.82.426 1.45v5.937h3.223v-5.607c0-.661.19-1.213.584-1.638.38-.425.9-.646 1.548-.646.569 0 .995.174 1.28.504.284.347.426.82.426 1.45v5.937h3.333v-6.442c0-1.307-.363-2.33-1.105-3.087-.743-.772-1.801-1.15-3.191-1.15zm13.664 6.474c-.11.33-.269.63-.506.898a2.488 2.488 0 0 1-.821.63 2.529 2.529 0 0 1-1.106.236 2.6 2.6 0 0 1-1.121-.236 2.336 2.336 0 0 1-.822-.63 3.139 3.139 0 0 1-.505-.898 3.262 3.262 0 0 1-.174-1.04c0-.362.063-.693.174-1.04.11-.33.284-.63.505-.881.221-.252.49-.473.822-.63a2.6 2.6 0 0 1 1.121-.236c.41 0 .79.078 1.106.236.332.157.6.362.821.63.221.252.395.551.506.882.11.33.158.677.158 1.04 0 .362-.048.708-.158 1.039zm1.769-4.962c-.506-.504-1.122-.897-1.832-1.197a6.346 6.346 0 0 0-2.37-.44c-.869 0-1.659.141-2.37.44a5.663 5.663 0 0 0-1.848 1.197 5.729 5.729 0 0 0-1.2 1.765 5.558 5.558 0 0 0-.427 2.173c0 .772.143 1.496.427
.733-.427.378-1.027.583-1.785.583a5.785 5.785 0 0 1-1.611-.205 5.91 5.91 0 0 1-1.375-.583l-1.342 2.268c.6.378 1.263.662 1.99.85.727.174 1.58.269 2.543.269 1.722 0 3.065-.41 4.06-1.229.995-.819 1.485-2.095 1.485-3.812V9.42a14.38 14.38 0 0 0-2.196-.551c-.79-.142-1.643-.22-2.543-.22zm13-.017c-.6 0-1.2.11-1.785.315-.584.22-1.058.52-1.405.93V4.473h-3.318V19.31h3.333v-5.607c0-.315.048-.598.143-.882.094-.268.237-.52.41-.724.19-.205.411-.378.695-.504.285-.126.6-.19.948-.19.537 0 .98.174  ...
# </g>
# </svg>
# </a>
# <button class="seo-mob-nav-display-action">
# <svg class="seo-mob-nav-display-action-svg" height="11px" version="1.1" viewbox="0 0 14 11" width="14px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>burger_menu</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g fill="#262637" transform="translate(-290.000000, -18.000000)">
# <g transform="translate(289.000000, 15.000000)">
# <path d="M15,13 L15,14 L1,14 L1,13 L15,13 Z M15,8 L15,9 L1,9 L1,8 L15,8 Z M15,3 L15,4 L1,4 L1,3 L15,3 Z" id="stroke"></path>
# </g>
# </g>
# </g>
# </svg>
# </button>
# <nav class="seo-nav">
# <div class="seo-nav-item buy">
# <a class="seo-nav-link" data-nav="buy" href="#">Buy</a>
# <div class="seo-nav-subNav">
# <ul class="seo-nav-subNav-col">
# <div>
# <li><a class="seo-nav-subNav-link" data-parent-nav="buy" href="/property-for-sale.html">Property for sale</a></li>
# <li><a class="seo-nav-subNav-link" data-parent-nav="buy" href="/new-homes-for-sale.html">New homes for sale</a></li>
# <li><a class="seo-nav-subNav-link" data-parent-nav="buy" href="https://where.rightmove.co.uk/">Where can I live</a></li>
# </div>
# </ul>
# <ul class="seo-nav-subNav-col">
# <div>
# <li><a class="seo-nav-subNav-link" data-parent-nav="buy" href="/property-valuation.html">Property valuation</a></li>
# <li><a class="seo-nav-subNav-link" data-parent-nav="buy" href="/advice/landlord/investor-newsletter/">Investors</a></li>
# <li><a class="seo-nav-subNav-link" data-parent-nav="buy" href="/advice/buyer/mortgages-financing/">Mortgages</a></li>
# </div>
# </ul>
# </div>
# </div>
# <div class="seo-nav-item rent">
# <a class="seo-nav-link" data-nav="rent" href="#">Rent</a>
# <div class="seo-nav-subNav">
# <ul class="seo-nav-subNav-col">
# <div>
# <li><a class="seo-nav-subNav-link" data-parent-nav="rent" href="/property-to-rent.html">Property to rent</a></li>
# <li><a class="seo-nav-subNav-link" data-parent-nav="rent" href="/student-accommodation.html">Student property to rent</a></li>
# <li><a class="seo-nav-subNav-link" data-parent-nav="rent" href="https://where.rightmove.co.uk">Where can I live</a></li>
# </div>
# </ul>
# </div>
# </div>
# <div class="seo-nav-item find-agent">
# <a class="seo-nav-link" data-nav="find-agent" href="#">Find Agent</a>
# <div class="seo-nav-subNav">
# <ul class="seo-nav-subNav-col">
# <div>
# <li><a class="seo-nav-subNav-link" data-parent-nav="find agent" href="/estate-agents.html">Find estate agents</a></li>
# </div>
# </ul>
# </div>
# </div>
# <div class="seo-nav-item-user" id="seo-nav-item-user">
# <a aria-label="Go to Sign In page" class="sign-in-link" href="/login.html" id="seo-nav-login-link" rel="nofollow">
# <span class="user-text">Sign In</span>
# <span class="user-svg">
# <svg class="core-svg" role="img">
# <use xlink:href="#account-silhouette"></use>
# </svg>
# </span>
# </a>
# <a aria-label="Go to My Rightmove page" class="account-link" href="/myrightmove.html" rel="nofollow">
# <span class="user-text">My Rightmove</span>
# <span class="user-svg">
# <svg class="core-svg" role="img">
# <use xlink:href="#account-silhouette"></use>
# </svg>
# </span>
# </a>
# </div>
# </nav>
# </div>
# <div class="seo-nav-subNav-background"></div>
# <div class="seo-nav-backdrop"></div>
# </div>
# <span id="seo-mob-nav-modal-background"></span>
# <span id="seo-mob-nav-modal-content">
# <header class="seo-mob-nav-header">
# <a class="seo-mob-nav-home-link seo-link" tabindex="-1">
# <svg class="seo-mob-nav-home-link-svg" height="25" viewbox="0 0 118 25" width="118" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M114.114 13.262h2.022V7.088l-5.56-4.662-5.56 4.662v6.174h2.021l3.554-2.993 3.523 2.993zm2.259 1.764h-2.907l-2.89-2.441-2.907 2.441h-2.906a1.507 1.507 0 0 1-1.517-1.528l.016-6.52c0-.41.158-.788.442-1.071l.063-.063 6.809-5.718 6.887 5.78c.284.284.442.662.442 1.072l.016 6.52c0 .41-.158.788-.442 1.087-.285.3-.695.441-1.106.441z" fill="#00DEB6"></path>
# <path d="M60.185 8.631c-.695 0-1.359.126-2.006.378a4.505 4.505 0 0 0-1.627 1.071 4.517 4.517 0 0 0-.474-.504c-.19-.173-.411-.33-.68-.472a4.138 4.138 0 0 0-.884-.347c-.348-.094-.727-.126-1.153-.126-.711 0-1.327.126-1.849.394-.52.268-.963.599-1.295 1.008l-.11-1.15h-3.191V19.31h3.333v-5.607c0-.661.19-1.213.584-1.638.395-.425.9-.646 1.548-.646.569 0 .995.174 1.28.504.284.347.426.82.426 1.45v5.937h3.223v-5.607c0-.661.19-1.213.584-1.638.38-.425.9-.646 1.548-.646.569 0 .995.174 1.28.504.284.347.426.82.426 1.45v5.937h3.333v-6.442c0-1.307-.363-2.33-1.105-3.087-.743-.772-1.801-1.15-3.191-1.15zm13.664 6.474c-.11.33-.269.63-.506.898a2.488 2.488 0 0 1-.821.63 2.529 2.529 0 0 1-1.106.236 2.6 2.6 0 0 1-1.121-.236 2.336 2.336 0 0 1-.822-.63 3.139 3.139 0 0 1-.505-.898 3.262 3.262 0 0 1-.174-1.04c0-.362.063-.693.174-1.04.11-.33.284-.63.505-.881.221-.252.49-.473.822-.63a2.6 2.6 0 0 1 1.121-.236c.41 0 .79.078 1.106.236.332.157.6.362.821.63.221.252.395.551.506.882.11.33.158.677.158 1.04 0 .362-.048.708-.158 1.039zm1.769-4.962c-.506-.504-1.122-.897-1.832-1.197a6.346 6.346 0 0 0-2.37-.44c-.869 0-1.659.141-2.37.44a5.663 5.663 0 0 0-1.848 1
.04.616.251 1.295.361 2.07.361 1.153 0 2.085-.283 2.78-.866v.74c0 .772-.222 1.355-.648 1.733-.427.378-1.027.583-1.785.583a5.785 5.785 0 0 1-1.611-.205 5.91 5.91 0 0 1-1.375-.583l-1.342 2.268c.6.378 1.263.662 1.99.85.727.174 1.58.269 2.543.269 1.722 0 3.065-.41 4.06-1.229.995-.819 1.485-2.095 1.485-3.812V9.42a14.38 14.38 0 0 0-2.196-.551c-.79-.142-1.643-.22-2.543-.22zm13-.017c-.6 0-1.2.11-1.785.315-.584.22-1.058.52-1.405.93V4.473h-3.318V19.31h3.333v-5.607c0-.315.048-.598.143-.882.094-.268.237-.52.41-.724.19-.205.411-.378.695-.504.285-.126.6-.19.948-.19.537 0 .98.174  ...
# </g>
# </svg>
# </a>
# <button aria-label="Close Navigation" class="seo-mob-nav-display-action close-button seo-link" tabindex="-1">
# <svg class="seo-mob-nav-display-action-svg" viewbox="0 0 10 10" xmlns="http://www.w3.org/2000/svg">
# <g stroke="none" stroke-width="1">
# <g>
# <path d="M9.85707844,0.13488598 C10.0360687,0.313876281 10.0361822,0.603963446 9.85767681,0.782468824 L0.781943042,9.85820259 C0.603283213,10.0368624 0.314598386,10.0378424 0.134360198,9.85760422 C-0.044630102,9.67861392 -0.0447435517,9.38852676 0.133761826,9.21002138 L9.2094956,0.134287608 C9.38815542,-0.0443722205 9.67684025,-0.0453522074 9.85707844,0.13488598 Z" id="Rectangle-468"></path>
# <path d="M0.781943042,0.134287608 C0.603283213,-0.0443722205 0.314598386,-0.0453522074 0.134360198,0.13488598 L0.134360198,0.13488598 C-0.044630102,0.313876281 -0.0447435517,0.603963446 0.133761826,0.782468824 L9.2094956,9.85820259 C9.38815542,10.0368624 9.67684025,10.0378424 9.85707844,9.85760422 L9.85707844,9.85760422 C10.0360687,9.67861392 10.0361822,9.38852676 9.85767681,9.21002138 L0.781943042,0.134287608 L0.781943042,0.134287608 Z" id="Rectangle-468"></path>
# </g>
# </g>
# </svg>
# </button>
# </header>
# <div id="seo-mob-nav-user">
# <span id="seo-mob-nav-profile-pic">
# <svg height="36px" version="1.1" viewbox="0 0 36 36" width="36px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>log_in</title>
# <g fill="none" fill-rule="evenodd" id="Current-designs-v2" stroke="none" stroke-width="1">
# <g id="Menu" transform="translate(-76.000000, -61.000000)">
# <g id="log_in" transform="translate(76.000000, 61.000000)">
# <circle cx="18" cy="18" fill="#53535F" id="Oval" r="18"></circle>
# <path d="M18.5,18.5 C16.4289322,18.5 14.75,16.8210678 14.75,14.75 C14.75,12.6789322 16.4289322,11 18.5,11 C20.5710678,11 22.25,12.6789322 22.25,14.75 C22.25,16.8210678 20.5710678,18.5 18.5,18.5 Z M17.15,19.25 L19.85,19.25 C21.589697,19.25 23,20.761039 23,22.625 L23,24.0714286 C23,25.1365492 22.1941125,26 21.2,26 L15.8,26 C14.8058875,26 14,25.1365492 14,24.0714286 L14,22.625 C14,20.761039 15.410303,19.25 17.15,19.25 Z" fill="#262637" id="stroke"></path>
# </g>
# </g>
# </g>
# </svg>
# </span>
# <a class="seo-mob-nav-account seo-link" href="/login.html" id="seo-mob-nav-sign-in" tabindex="-1">Sign in</a>
# <a class="seo-mob-nav-account seo-link" href="/myrightmove.html" id="seo-mob-nav-my-rightmove" tabindex="-1">My Rightmove</a>
# </div>
# <div class="seo-mob-nav-link-group">
# <div class="seo-mob-nav-link-group-title">Buy</div>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/property-for-sale.html" tabindex="-1">Property for sale</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/new-homes-for-sale.html" tabindex="-1">New homes for sale</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/property-valuation.html" tabindex="-1">Property valuation</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="https://where.rightmove.co.uk/" tabindex="-1">Where can I live</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/advice/landlord/investor-newsletter/" tabindex="-1">Investors</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/advice/buyer/mortgages-and-financing/" tabindex="-1">Mortgages</a>
# </div>
# <div class="seo-mob-nav-link-group">
# <div class="seo-mob-nav-link-group-title">Rent</div>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="rent" href="/property-to-rent.html" tabindex="-1">Property to rent</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="rent" href="/student-accommodation.html" tabindex="-1">Student property to rent</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="rent" href="https://where.rightmove.co.uk/" tabindex="-1">Where can I live</a>
# </div>
# <div class="seo-mob-nav-link-group">
# <div class="seo-mob-nav-link-group-title">House prices</div>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="house prices" href="/house-prices.html" tabindex="-1">Sold house prices</a>
# </div>
# <div class="seo-mob-nav-link-group">
# <div class="seo-mob-nav-link-group-title">Commercial</div>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="commercial" href="/commercial-property-to-let.html" tabindex="-1">Commercial property to rent</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="commercial" href="/commercial-property-for-sale.html" tabindex="-1">Commercial property for sale</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="commercial" href="/c/commercial-advertising/" tabindex="-1">Advertise</a>
# </div>
# <div class="seo-mob-nav-link-group">
# <div class="seo-mob-nav-link-group-title">Inspire</div>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/moving-stories/" tabindex="-1">Moving stories</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/news/" tabindex="-1">Property blog</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/advice/" tabindex="-1">Property advice</a>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/news/house-price-index/" tabindex="-1">Housing trends</a>
# </div>
# <div class="seo-mob-nav-link-group">
# <div class="seo-mob-nav-link-group-title">Visit Rightmove overseas</div>
# <a class="seo-mob-nav-link seo-link" data-parent-nav="overseas" href="/overseas-property.html" tabindex="-1">
#                         Overseas property for sale
#                         <span class="seo-mob-nav-oversea-img">
# <svg height="12px" version="1.1" viewbox="0 0 15 14" width="15px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Overseas properties</title>
# <g fill="none" fill-rule="evenodd" id="Search-results-V2" stroke="none" stroke-width="1">
# <g fill="#262637" id="Search-results" transform="translate(-857.000000, -2259.000000)">
# <g id="05.Icons/SM/new-window" transform="translate(857.000000, 2257.000000)">
# <path d="M7,2 L7,3 L1,3 L1,15.0000122 L13,15.0000122 L13,9 L14,9 L14,16.0000122 L0,16.0000122 L0,2 L7,2 Z M14.0146212,2.00421356 L14.0146212,6.33264069 L13.0146212,6.33264069 L13.0135228,3.71148513 L7.85776695,8.86817459 L7.15066017,8.16106781 L12.306416,3.00437835 L9.68619408,3.00421356 L9.68619408,2.00421356 L14.0146212,2.00421356 Z" id="Combined-Shape"></path>
# </g>
# </g>
# </g>
# </svg>
# </span>
# </a>
# </div>
# </span>
# </header>
# <style>
# 		.seo-mob-nav-header {
# 			display: -ms-flex;
# 			display: -webkit-flex;
# 			display: flex;
# 			height: 50px;
#
# 			justify-content: center;
# 		}
#
# 		.seo-mob-nav-home-link {
# 			height: 50px;
#
# 			display: -ms-inline-flexbox;
# 			display: -webkit-inline-flex;
# 			display: inline-flex;
#
# 			align-items: center;
# 		}
#
# 		.seo-mob-nav-home-link-svg {
# 		    height: 25px !important;
# 		    width: 118px !important;
# 		}
#
# 		.seo-mob-nav-display-action {
# 			height: 50px;
# 			width: 50px;
# 			padding: 17px;
# 			margin: 0;
# 			border: 0;
# 			background-color: #ffffff;
#
# 			position: absolute;
# 			right: 0;
# 		}
#
# 		.seo-mob-nav-display-action-svg {
# 		    height: 12px !important;
# 		    width: 12px !important;
# 		}
#
# 		#seo-mob-nav-modal-background {
# 			width: 0;
# 			height: 100vh;
# 			background-color: rgba(83, 83, 95, 0.8);
# 			display: block;
# 			position: fixed;
# 			top: 0;
# 			right: 0;
#
# 			z-index: 9998;
#
# 			transition: opacity 400ms ease;
# 		}
#
# 		#seo-mob-nav-modal-content {
# 			position: fixed;
# 			top: 0;
# 			bottom: 0;
# 			right: 0;
# 			width: 0;
#
# 			z-index: 9999;
#
# 			background-color: white;
# 			overflow-y: scroll;
# 			transition: width 400ms ease;
# 		}
#
# 		.seo-link {
# 			tab-index: -1;
# 		}
#
# 		#seo-mob-nav-user {
# 			height: 67px;
# 			background-color: #262637;
# 			padding-left: 16px;
#
# 			display: -ms-flex;
# 			display: -webkit-flex;
# 			display: flex;
#
# 			-ms-flex-direction: row;
# 			-moz-flex-direction: row;
# 			-webkit-flex-direction: row;
# 			flex-direction: row;
#
# 			align-items: center;
# 		}
#
# 		#seo-mob-nav-user.authed #seo-mob-nav-sign-in {
# 			display: none;
# 		}
#
# 		#seo-mob-nav-user.authed #seo-mob-nav-my-rightmove {
# 			display: block;
# 		}
#
# 		#seo-mob-nav-user #seo-mob-nav-sign-in {
# 			display: block;
# 		}
#
# 		#seo-mob-nav-user #seo-mob-nav-my-rightmove {
# 			display: none;
# 		}
#
# 		#seo-mob-nav-profile-pic {
# 			width: 36px;
# 			height: 36px;
# 			margin-right: 16px;
# 		}
#
# 		.seo-mob-nav-account {
# 			font-size: 16px;
# 			-webkit-font-smoothing: antialiased;
# 			font-weight: 500;
# 			color: #FFFFFF;
# 			text-decoration: none;
# 		}
#
# 		.seo-mob-nav-link-group {
# 			margin: 0 16px;
# 			padding: 16px 0;
# 			border-bottom: 1px solid #DFDFE1;
# 		}
#
# 		.seo-mob-nav-link-group-title {
# 			font-size: 16px;
# 			-webkit-font-smoothing: antialiased;
# 			font-weight: 500;
# 			color: #262637;
# 			line-height: 24px;
# 			margin-bottom: 4px;
# 		}
#
# 		.seo-mob-nav-link {
# 			display: block;
# 			padding: 0 8px;
# 			font-size: 16px;
# 			-webkit-font-smoothing: antialiased;
# 			font-weight: 400;
# 			color: #717184;
# 			line-height: 24px;
# 			white-space: nowrap;
# 			text-decoration: none;
# 		}
#
# 		.seo-mob-nav-oversea-img {
# 		    height: 12px !important;
# 		    width: 12px !important;
# 		    display: inline-block !important;
# 		}
#
# 		.seo-header-container {
# 			background-color: #ffffff;
# 			border-bottom: 1px solid #D5D5D5;
# 		}
#
# 		.seo-header {
# 			height: 50px;
# 			width: 100%;
# 			max-width: 1180px;
# 			margin: 0 auto;
#
# 			display: flex;
# 			flex-direction: row;
# 			justify-content: center;
# 			align-items: center;
# 		}
# 		.seo-header .seo-logo {
# 			float: left;
# 			height: 50px;
# 			padding: 12px;
# 			position: absolute;
# 			box-sizing: border-box;
# 		}
# 		.seo-nav {
# 			display: none;
# 		}
#
# 		@media (min-width: 1070px) {
# 			.seo-nav {
# 				display: block;
# 				background-color: transparent;
# 				-webkit-box-shadow: none;
# 				box-shadow: none;
# 				text-align: right;
# 				float: right;
# 			}
# 			.seo-nav .seo-nav-item {
# 				display: none;
# 			}
# 			.seo-nav .seo-nav-item-user {
# 				float: left;
# 				display: none;
# 				height: 50px;
# 			}
# 			.seo-nav .seo-nav-item-user .user-svg {
# 				right: 0;
# 				height: 50px;
# 				padding: 16px;
# 				display: inline-block;
# 				float: left;
# 			}
# 			.seo-nav .seo-nav-item-user .user-svg img, .seo-nav .seo-nav-item-user .user-svg svg {
# 				fill: #DFDFE1;
# 				width: 20px;
# 				height: 20px;
# 			}
# 			.seo-nav .seo-nav-item-user .user-text {
# 				display: none;
# 			}
# 			.seo-nav .seo-nav-item-user .sign-in-link {
# 				display: inline-block;
# 			}
# ...
# </ul>
# </li>
# <li class="globalFooter-menuGroup" data-bind="css : {'globalFooter-menuGroup--expanded': isFooterItemOpen('professional')}">
# <h4 class="globalFooter-menuGroupHeader" data-bind="click: openFooterMenu('professional')">
# <span>Professional</span>
# <div class="no-svg-chevron-line globalFooter-chevron">
# <svg>
# <use xlink:href="#core-icon--chevron-line">
# </use></svg>
# </div>
# </h4>
# <ul class="globalFooter-subMenu">
# <li class="globalFooter-subMenuItem-black" id="fs-customer-link-menu-item">
# <a class="globalFooter-subMenuLink" href="https://rmplusportal.rightmove.co.uk" title="Rightmove Plus">Rightmove Plus</a>
# </li>
# <li class="globalFooter-subMenuItem"><a class="globalFooter-subMenuLink" href="/data/" title="Data Services">Data Services</a></li>
# <li class="globalFooter-subMenuItem"><a class="globalFooter-subMenuLink" href="/for-agents.html" title="Agents and Developers">Agents and Developers</a></li>
# <li class="globalFooter-subMenuItem"><a class="globalFooter-subMenuLink" href="/overseas-property/advertise.html" title="Overseas Agents and Developers">Overseas Agents and Developers</a></li>
# <li class="globalFooter-subMenuItem"><a class="globalFooter-subMenuLink" href="/c/display-advertising/" title="Home and Property Related Services">Home and Property Related Services</a></li>
# <li class="globalFooter-subMenuItem"><a class="globalFooter-subMenuLink" href="/c/commercial-advertising/" title="Advertise commercial property">Advertise commercial property</a></li>
# </ul>
# </li>
# </ul>
# <div class="globalFooter-menuFooter">
# <div class="globalFooter-legal">
# <span class="globalFooter-legalTitle">This site:</span>
# <a class="globalFooter-legalLink" href="/site-map.html">Site map</a>
# <a class="globalFooter-legalLink globalFooter-legalLink--secondary" href="https://faq.rightmove.co.uk/support/home">Help</a>
# <a class="globalFooter-legalLink optanon-show-settings-button optanon-toggle-display" href="/this-site/cookies.html" target="_blank">Cookies</a>
# <a class="globalFooter-legalLink globalFooter-legalLink--secondary" href="/advice/safety-and-security/">Safety and security</a>
# <a class="globalFooter-legalLink" href="/this-site/terms-of-use.html">Terms of Use</a>
# <a class="globalFooter-legalLink" href="/this-site/privacy-policy.html">Privacy Policy</a>
# </div>
# <div class="globalFooter-cities">
# <span class="globalFooter-citiesHeader">Major cities and towns in the UK:</span>
# <div class="select-wrapper globalFooter-citiesSelectWrapper">
# <select class="select globalFooter-citiesSelect" data-bind="value: citiesSelectValue" title="Major cities and towns in the UK">
# <option selected="selected" value="">Select (A-Z)</option>
# <optgroup label="United Kingdom:">
# <option value="/uk-property-search-a-be.html">A-Be</option>
# <option value="/uk-property-search-bl-bu.html">Bl-Bu</option>
# <option value="/uk-property-search-ca-ce.html">Ca-Ce</option>
# <option value="/uk-property-search-ch-con.html">Ch-Con</option>
# <option value="/uk-property-search-cor-cu.html">Cor-Cu</option>
# <option value="/uk-property-search-d.html">D</option>
# <option value="/uk-property-search-ea.html">Ea</option>
# <option value="/uk-property-search-ed-f.html">Ed-F</option>
# <option value="/uk-property-search-g.html">G</option>
# <option value="/uk-property-search-h.html">H</option>
# <option value="/uk-property-search-i-k.html">I-K</option>
# <option value="/uk-property-search-l.html">L</option>
# <option value="/uk-property-search-m-ne.html">M-Ne</option>
# <option value="/uk-property-search-no.html">No</option>
# <option value="/uk-property-search-o-r.html">O-R</option>
# <option value="/uk-property-search-sc-so.html">Sc-So</option>
# <option value="/uk-property-search-st-sw.html">St-Sw</option>
# <option value="/uk-property-search-t-v.html">T-V</option>
# <option value="/uk-property-search-wa-we.html">Wa-We</option>
# <option value="/uk-property-search-wi-wr.html">Wi-Wr</option>
# <option value="/uk-property-search-y.html">Y</option>
# <option value="/commercial-property-to-let/Soho/offices.html">Offices to Rent in Soho</option>
# <option value="/commercial-property-to-let/Birmingham/serviced-offices.html">Serviced Offices to Rent in Birmingham</option>
# <option value="/commercial-property-to-let/Bristol/serviced-offices.html">Serviced Offices to Rent in Bristol</option>
# <option value="/commercial-property-to-let/Glasgow/serviced-offices.html">Serviced Offices to Rent in Glasgow</option>
# <option value="/commercial-property-to-let/Leeds/serviced-offices.html">Serviced Offices to Rent in Leeds</option>
# <option value="/commercial-property-to-let/Leicester/serviced-offices.html">Serviced Offices to Rent in Leicester</option>
# <option value="/commercial-property-to-let/London/serviced-offices.html">Serviced Offices to Rent in London</option>
# <option value="/commercial-property-to-let/Manchester/serviced-offices.html">Serviced Offices to Rent in Manchester</option>
# <option value="/commercial-property-to-let/Newcastle-Upon-Tyne/serviced-offices.html">Serviced Offices to Rent in Newcastle Upon Tyne</option>
# <option value="/commercial-property-to-let/Nottingham/serviced-offices.html">Serviced Offices to Rent in Nottingham</option>
# <option value="/commercial-property-to-let/Soho/serviced-offices.html">Serviced Offices to Rent in Soho</option>
# </optgroup>
# </select>
# <svg class="no-svg-chevron select-chevron">
# <use xlink:href="#core-icon--chevron"></use>
# </svg>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-policy-wrapper" data-bind="css: { 'is-visible' : showMessage }" data-test="cookie-policy-wrapper" id="cookiePolicy">
# <div>
# <p>
# <span>We use cookies</span>
#             to optimise your experience on our website.
#             If you continue we'll assume that you are happy to receive our cookies.
#             However, if you would like to, you can
#             <a href="/this-site/cookies.html">change your cookie settings</a>
#             at any time.
#         </p>
# <button class="button" data-bind="click: closeMessage" data-test="close-cookie-popup-button">
# <span class="button-icon">
# <svg>
# <use xlink:href="#core-icon--checkbox-tick"></use>
# </svg>
# </span>
# <span>Continue</span>
# </button>
# </div>
# </div><script>window.jsonModel = {"properties":[{"id":97203149,"bedrooms":2,"numberOfImages":20,"numberOfFloorplans":1,"numberOfVirtualTours":0,"summary":"A contemporary 2 double bedroom apartment with a large private patio (111 Sq Ft) set within the heart of Camden Town; popular development named - Camden Courtyards. The property's sought-after location in the heart of central London means there are an abundance of nearby travel stations. EPC-B","displayAddress":"Camden Courtyards, St Pancras Way, Camden, NW1","countryCode":"GB","location":{"latitude":51.54299,"longitude":-0.13786},"propertySubType":"Duplex","listingUpdate":{"listingUpdateReason":"new","listingUpdateDate":"2020-09-12T22:22:01Z"},"premiumListing":true,"featuredProperty":true,"price":{"amount":595,"frequency":"weekly","currencyCode":"GBP","displayPrices":[{"displayPrice":"£2,578 pcm","displayPriceQualifier":""},{"displayPrice":"£595 pw","displayPriceQualifier":""}]},"customer":{"branchId":32781,"brandPlusLogoURI":"/company/clogo_rmchoice_25985_0000.jpeg","contactTelephone":"020 8012 1548","branchDisplayName":"Benham & Reeves, Hyde Park","branchName":"Hyde Park","brandTradingName":"Benham & Reeves","branchLandingPageUrl":"/estate-agents/agent/Benham-and-Reeves/Hyde-Park-32781.html","development":false,"showReducedProperties":true,"commercial":false,
#             value: 'park-home',
#             name: 'Park Home',
#             categoryId: ''
#         }];
#
#         window.jsonModel.propertyTypeOptions.parentCategories = [{
#             name: 'General',
#             value: 'General',
#             children: []
#         }];
#         window.jsonModel.propertyTypeOptions.groupSize = 4;
#     </script><script>
#     window.jsonModel.propertyTypeOptions = {};
#     window.jsonModel.propertyTypeOptions.propertyTypes = [{
#         value: 'detached',
#         name: 'Detached',
#         categoryId: ''
#     }, {
#         value: 'semi-detached',
#         name: 'Semi-detached',
#         categoryId: ''
#     }, {
#         value: 'terraced',
#         name: 'Terraced',
#         categoryId: ''
#     }, {
#         value: 'flat',
#         name: 'Flat',
#         categoryId: ''
#     }, {
#         value: 'bungalow',
#         name: 'Bungalow',
#         categoryId: ''
#     }, {
#         value: 'land',
#         name: 'Land',
#         categoryId: ''
#     }, {
#         value: 'park-home',
#         name: 'Park Home',
#         categoryId: ''
#     }, {
#         value: 'private-halls',
#         name: 'Student Halls',
#         categoryId: ''
#     }];
#
#     window.jsonModel.propertyTypeOptions.parentCategories = [{
#         name: 'General',
#         value: 'General',
#         children: []
#     }];
#     window.jsonModel.propertyTypeOptions.groupSize = 4;
# </script><script defer="" src="/pvw/javascript/search-vendor.a82889e3fcf0f9bfd968.js"></script>
# <script defer="" src="/pvw/javascript/property-to-rent.search.f09419055721a1d83183.js"></script></body>
# </html>
# >

# %%
# We know that the link to the page will be stored within a href so let's analyze some of the reference instances from the first page
for item in bs.findAll("a",href=True):

        print("{} \n".format(item))
# Out:
# <a aria-label="Go to Rightmove homepage" class="seo-logo" href="/">
# <svg height="25" viewbox="0 0 118 25" width="118" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M114.114 13.262h2.022V7.088l-5.56-4.662-5.56 4.662v6.174h2.021l3.554-2.993 3.523 2.993zm2.259 1.764h-2.907l-2.89-2.441-2.907 2.441h-2.906a1.507 1.507 0 0 1-1.517-1.528l.016-6.52c0-.41.158-.788.442-1.071l.063-.063 6.809-5.718 6.887 5.78c.284.284.442.662.442 1.072l.016 6.52c0 .41-.158.788-.442 1.087-.285.3-.695.441-1.106.441z" fill="#00DEB6"></path>
# <path d="M60.185 8.631c-.695 0-1.359.126-2.006.378a4.505 4.505 0 0 0-1.627 1.071 4.517 4.517 0 0 0-.474-.504c-.19-.173-.411-.33-.68-.472a4.138 4.138 0 0 0-.884-.347c-.348-.094-.727-.126-1.153-.126-.711 0-1.327.126-1.849.394-.52.268-.963.599-1.295 1.008l-.11-1.15h-3.191V19.31h3.333v-5.607c0-.661.19-1.213.584-1.638.395-.425.9-.646 1.548-.646.569 0 .995.174 1.28.504.284.347.426.82.426 1.45v5.937h3.223v-5.607c0-.661.19-1.213.584-1.638.38-.425.9-.646 1.548-.646.569 0 .995.174 1.28.504.284.347.426.82.426 1.45v5.937h3.333v-6.442c0-1.307-.363-2.33-1.105-3.087-.743-.772-1.801-1.15-3.191-1.15zm13.664 6.474c-.11.33-.269.63-.506.898a2.488 2.488 0 0 1-.
a>
#
# <a class="seo-nav-subNav-link" data-parent-nav="overseas" href="/overseas-property/hot-properties.html">Hot properties</a>
#
# <a class="seo-nav-subNav-link" data-parent-nav="overseas" href="/overseas-property/in-Spain.html">Spain</a>
#
# <a class="seo-nav-subNav-link" data-parent-nav="overseas" href="/overseas-property/in-France.html">France</a>
#
# <a class="seo-nav-subNav-link" data-parent-nav="overseas" href="/overseas-property/help-and-advice/research.html">Help and advice</a>
#
# <a class="seo-nav-subNav-link" data-parent-nav="overseas" href="/overseas-property/advertise.html">Sell overseas property</a>
#
# <a aria-label="Go to Sign In page" class="sign-in-link" href="/login.html" id="seo-nav-login-link" rel="nofollow">
# <span class="user-text">Sign In</span>
# <span class="user-svg">
# <svg class="core-svg" role="img">
# <use xlink:href="#account-silhouette"></use>
# </svg>
# </span>
# </a>
#
# <a aria-label="Go to My Rightmove page" class="account-link" href="/myrightmove.html" rel="nofollow">
# <span class="user-text">My Rightmove</span>
# <span class="user-svg">
# <svg class="core-svg" role="img">
# <use xlink:href="#account-silhouette"></use>
# </svg>
# </span>
# </a>
#
# <a class="seo-mob-nav-account seo-link" href="/login.html" id="seo-mob-nav-sign-in" tabindex="-1">Sign in</a>
#
# <a class="seo-mob-nav-account seo-link" href="/myrightmove.html" id="seo-mob-nav-my-rightmove" tabindex="-1">My Rightmove</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/property-for-sale.html" tabindex="-1">Property for sale</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/new-homes-for-sale.html" tabindex="-1">New homes for sale</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/property-valuation.html" tabindex="-1">Property valuation</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="https://where.rightmove.co.uk/" tabindex="-1">Where can I live</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/advice/landlord/investor-newsletter/" tabindex="-1">Investors</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="buy" href="/advice/buyer/mortgages-and-financing/" tabindex="-1">Mortgages</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="rent" href="/property-to-rent.html" tabindex="-1">Property to rent</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="rent" href="/student-accommodation.html" tabindex="-1">Student property to rent</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="rent" href="https://where.rightmove.co.uk/" tabindex="-1">Where can I live</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="house prices" href="/house-prices.html" tabindex="-1">Sold house prices</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="commercial" href="/commercial-property-to-let.html" tabindex="-1">Commercial property to rent</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="commercial" href="/commercial-property-for-sale.html" tabindex="-1">Commercial property for sale</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="commercial" href="/c/commercial-advertising/" tabindex="-1">Advertise</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/moving-stories/" tabindex="-1">Moving stories</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/news/" tabindex="-1">Property blog</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/advice/" tabindex="-1">Property advice</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="inspire" href="/news/house-price-index/" tabindex="-1">Housing trends</a>
#
# <a class="seo-mob-nav-link seo-link" data-parent-nav="overseas" href="/overseas-property.html" tabindex="-1">
#                         Overseas property for sale
#                         <span class="seo-mob-nav-oversea-img">
# <svg height="12px" version="1.1" viewbox="0 0 15 14" width="15px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Overseas properties</title>
# <g fill="none" fill-rule="evenodd" id="Search-results-V2" stroke="none" stroke-width="1">
# <g fill="#262637" id="Search-results" transform="translate(-857.000000, -2259.000000)">
# <g id="05.Icons/SM/new-window" transform="translate(857.000000, 2257.000000)">
# <path d="M7,2 L7,3 L1,3 L1,15.0000122 L13,15.0000122 L13,9 L14,9 L14,16.0000122 L0,16.0000122 L0,2 L7,2 Z M14.0146212,2.00421356 L14.0146212,6.33264069 L13.0146212,6.33264069 L13.0135228,3.71148513 L7.85776695,8.86817459 L7.15066017,8.16106781 L12.306416,3.00437835 L9.68619408,3.00421356 L9.68619408,2.00421356 L14.0146212,2.00421356 Z" id="Combined-Shape"></path>
# </g>
# </g>
# </g>
# </svg>
# </span>
# </a>
#
# <a class="info-letAgreedFilter" data-bind="click: openMoreInfoPopup('letAgreed')" href="/letAgreed.html" rel="nofollow" target="_blank" title="Further information">?</a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-97203149.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/33k/32781/97203149/32781_ccspwcl0912_IMG_00_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-97203149.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# <div class="propertyCard-additionalImg aspect-3x2 propertyCard-additionalImg--gridLayout">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-97203149.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£2,578 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-97203149.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-97203149.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label">High Specification</div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Benham-and-Reeves/Hyde-Park-32781.html" title="Benham &amp; Reeves, Hyde Park">
# <img alt="Benham &amp; Reeves, Hyde Park Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-97203149.html">
# <h2 class="propertyCard-title" itemprop="name">
#             2 bedroom duplex        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Camden Courtyards, St Pancras Way, Camden, NW1" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Camden Courtyards, St Pancras Way, Camden, NW1</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-97203149.html">
# <span data-test="property-description" itemprop="description">A contemporary 2 double bedroom apartment with a large private patio (111 Sq Ft) set within the heart of Camden Town; popular development named - Camden Courtyards. The property's sought-after location in the heart of central London means there are an abundance of nearby travel stations. EPC-B</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Benham-and-Reeves/Hyde-Park-32781.html" title="Benham &amp; Reeves, Hyde Park">
# <img alt="Benham &amp; Reeves, Hyde Park Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-96892889.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/21k/20234/96892889/20234_221Streatham_IMG_00_0000_max_476x317.JPG"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-96892889.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-96892889.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-96892889.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-96892889.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/P4I/London-20234.html" title="P4I, London">
# <img alt="P4I, London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-96892889.html">
# <h2 class="propertyCard-title" itemprop="name">
#             1 bedroom flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Streatham High Road, London, SW16" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Streatham High Road, London, SW16</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-96892889.html">
# <span data-test="property-description" itemprop="description">P4i are pleased to offer this brand new one bedroom flat, located on Streatham High Road, SW16 6EN</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/P4I/London-20234.html" title="P4I, London">
# <img alt="P4I, London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-82780999.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/118k/117484/82780999/117484_10409286_IMG_11_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-82780999.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-82780999.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-82780999.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-82780999.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Choices/Central-London-117484.html" title="Choices, Central London">
# <img alt="Choices, Central London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-82780999.html">
# <h2 class="propertyCard-title" itemprop="name">
#             1 bedroom flat share        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Large Double Room - Belvedere Road, SE1" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Large Double Room - Belvedere Road, SE1</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-82780999.html">
# <span data-test="property-description" itemprop="description">Large Double Room in this this three bedroom apartment within the prestigious County Hall Development. Rent is £1000 per month excluding bills. SHARES MAIN BATHROOM WITH ONE TENANT. Moments from the banks of the River Thames and The London Eye. The property boasts a master b...</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Choices/Central-London-117484.html" title="Choices, Central London">
# <img alt="Choices, Central London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-78396658.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/54k/53010/78396658/53010_101541006071_IMG_01_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-78396658.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-78396658.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-78396658.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-78396658.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/mile/Kensal-Rise-53010.html" title="mile... , Kensal Rise">
# <img alt="mile... , Kensal Rise Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-78396658.html">
# <h2 class="propertyCard-title" itemprop="name">
#             Studio flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Belsize Avenue, London NW3" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Belsize Avenue, London NW3</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-78396658.html">
# <span data-test="property-description" itemprop="description">*** INCLUDES ALL BILLS &amp; INTERNET *** Mile is delighted to offer this fantastic double studio apartment set in this beautiful Victorian property which is located on Belsize Avenue in the heart of Belsize Park. The galleried studio is offered in excellent condition and benefits from fitted d...</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/mile/Kensal-Rise-53010.html" title="mile... , Kensal Rise">
# <img alt="mile... , Kensal Rise Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-72653577.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/7k/6843/72653577/6843_101841000595_IMG_01_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-72653577.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-72653577.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-72653577.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-72653577.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Oliver-Jaques/Surrey-Quays-6843.html" title="Oliver Jaques, Surrey Quays">
# <img alt="Oliver Jaques, Surrey Quays Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-72653577.html">
# <h2 class="propertyCard-title" itemprop="name">
#             Studio flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Windsock Close , Surrey Quays" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Windsock Close , Surrey Quays</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-72653577.html">
# <span data-test="property-description" itemprop="description">A well presented studio apartment set within this modern purpose built development overlooking South Dock Marina. The property has been maintained to a high standard and comprises, spacious living room/bedroom with plenty of storage space, fully fitted kitchen, and three piece bathroom suite. Id...</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Oliver-Jaques/Surrey-Quays-6843.html" title="Oliver Jaques, Surrey Quays">
# <img alt="Oliver Jaques, Surrey Quays Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-72090972.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/36k/35945/72090972/35945_onebedapartmentkatherine_IMG_00_0000_max_476x317.JPG"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-72090972.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-72090972.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-72090972.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-72090972.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Marvel-and-Co/Forest-Gate-35945.html" title="Marvel &amp; Co, Forest Gate">
# <img alt="Marvel &amp; Co, Forest Gate Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-72090972.html">
# <h2 class="propertyCard-title" itemprop="name">
#             1 bedroom apartment        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Katherine Road, London, E7" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Katherine Road, London, E7</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-72090972.html">
# <span data-test="property-description" itemprop="description">Situated on Katherine Road is this lovely and contemporary one bedroom apartment for rent. Comprising of a large double bedroom,open plan kitchen and lounge with white goods leading onto balcony. Modern and also spacious bathroom.Only a short walk to East Ham or Upton Park tube station and amenities</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Marvel-and-Co/Forest-Gate-35945.html" title="Marvel &amp; Co, Forest Gate">
# <img alt="Marvel &amp; Co, Forest Gate Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-81405292.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/77k/76316/81405292/76316_29753435_IMG_09_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-81405292.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-81405292.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-81405292.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-81405292.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Beaumont-Gibbs/Plumstead-76316.html" title="Beaumont Gibbs, Plumstead">
# <img alt="Beaumont Gibbs, Plumstead Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-81405292.html">
# <h2 class="propertyCard-title" itemprop="name">
#             1 bedroom flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Calderwood Street, Woolwich, London, SE18 " itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Calderwood Street, Woolwich, London, SE18 </span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-81405292.html">
# <span data-test="property-description" itemprop="description">* SEE WALKTHROUGH VIDEO TOUR * ONE DOUBLE BEDROOMED FIRST FLOOR FLAT * UNFURNISHED BUT WITH WHAITE GOODS TO REMAIN * AVAILABLE FIRST WEEK OF AUGUST * IN THE CENTRE OF WOOLWICH * CLOSE TO DLR &amp; MAINLINE STATION * DOUBLE GLAZING * ELECTRIC STORAGE HEATING * ONSITE CONCIERGE * CALL TO VIEW NOW. Fan...</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Beaumont-Gibbs/Plumstead-76316.html" title="Beaumont Gibbs, Plumstead">
# <img alt="Beaumont Gibbs, Plumstead Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-92446088.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/87k/86576/92446088/86576_345_IMG_03_0000_max_476x317.JPG"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-92446088.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-92446088.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-92446088.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-92446088.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/John-Dean/London-86576.html" title="John Dean, London">
# <img alt="John Dean, London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-92446088.html">
# <h2 class="propertyCard-title" itemprop="name">
#             Studio flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Balham High Road, London, SW17" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Balham High Road, London, SW17</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-92446088.html">
# <span data-test="property-description" itemprop="description">A fifth floor studio flat, outward facing overlooking a pretty front courtyard. Conveniently placed for both tube and train as well as many shops, eateries and bars etc. </span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/John-Dean/London-86576.html" title="John Dean, London">
# <img alt="John Dean, London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-96129956.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/79k/78489/96129956/78489_11583_AGRN_IMG_01_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-96129956.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-96129956.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-96129956.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-96129956.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Charles-Henry-Peppiatt-Ltd/Kentish-Town-78489.html" title="Charles Henry Peppiatt Ltd, Kentish Town">
# <img alt="Charles Henry Peppiatt Ltd, Kentish Town Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-96129956.html">
# <h2 class="propertyCard-title" itemprop="name">
#             Studio flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Roderick Road, Hampstead" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Roderick Road, Hampstead</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-96129956.html">
# <span data-test="property-description" itemprop="description">This beautifully presented studio apartment is set on the first floor of a charming period property, superbly located close to both Belsize Park and Hampstead stations. It has wood flooring throughout, a modern fully fitted kitchen, modern shower room and double glazed windows.</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/Charles-Henry-Peppiatt-Ltd/Kentish-Town-78489.html" title="Charles Henry Peppiatt Ltd, Kentish Town">
# <img alt="Charles Henry Peppiatt Ltd, Kentish Town Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-69433539.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/54k/53010/69433539/53010_101541006075_IMG_01_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-69433539.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# ...
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/mile/Colindale-178880.html" title="mile... , Colindale">
# <img alt="mile... , Colindale Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-82132021.html">
# <h2 class="propertyCard-title" itemprop="name">
#             Studio flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Belsize Avenue, London NW3" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Belsize Avenue, London NW3</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-82132021.html">
# <span data-test="property-description" itemprop="description">*** INCLUDES ALL BILLS &amp; INTERNET *** Mile is delighted to offer this fantastic double studio apartment set in this beautiful Victorian property which is located on Belsize Avenue in the heart of Belsize Park. The galleried studio is offered in excellent condition and benefits from fitted d...</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/mile/Colindale-178880.html" title="mile... , Colindale">
# <img alt="mile... , Colindale Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-img-link aspect-3x2" data-test="property-img" href="/property-to-rent/property-83673007.html">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Property Image 1" itemprop="image" src="https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/97k/96668/83673007/96668_76303011042020_IMG_01_0000_max_476x317.jpg"/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </a>
#
# <a class="propertyCard-additionalImgs" href="/property-to-rent/property-83673007.html" title="Additional property images">
# <div class="propertyCard-additionalImg aspect-3x2">
# <div class="propertyCard-img">
# <div class="no-svg-camera camera">
# <svg>
# <use xlink:href="#core-icon--camera">
# </use></svg>
# </div>
# <img alt="Placeholder Image" src=""/>
# <span class="propertyCard-awaitingImage"> <div class="no-svg-awaiting-image">
# <svg>
# <use xlink:href="#core-icon--awaiting-image">
# </use></svg>
# </div>
# </span>
# </div>
# </div>
# </a>
#
# <a class="propertyCard-priceLink propertyCard-rentalPrice" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-83673007.html">
# <div class="propertyCard-rentalPrice-primary">
# <span class="propertyCard-priceValue" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPrice : ''">£1,000 pcm</span>
# <span class="propertyCard-priceQualifier" data-bind="text: price.displayPrices()[0] ? price.displayPrices()[0].displayPriceQualifier : ''"></span>
# </div>
# </a>
#
# <a class="propertyCard-priceLink" data-bind="click: propertyCardClick('price'), attr: { href: computedDetailsLink() }" data-test="property-header" href="/property-to-rent/property-83673007.html">
# <span class="propertyCard-secondaryPriceValue" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPrice : ''"></span>
# <span class="propertyCard-secondaryPriceQualifier" data-bind="text: price.displayPrices()[1] ? price.displayPrices()[1].displayPriceQualifier : ''"></span>
# </a>
#
# <a class="propertyCard-headerLink" href="/property-to-rent/property-83673007.html">
# <div class="propertyCard-premiumLabel" data-test="property-premium-label"></div>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/OpenRent/London-96668.html" title="OpenRent, London">
# <img alt="OpenRent, London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-83673007.html">
# <h2 class="propertyCard-title" itemprop="name">
#             1 bedroom flat        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Hoe Street, London, E17" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Hoe Street, London, E17</span>
# </address>
# </a>
#
# <a class="propertyCard-link" href="/property-to-rent/property-83673007.html">
# <span data-test="property-description" itemprop="description">A modern built flatin the heart of Walthamstow. A few minutes from Walthamstow Underground, Busand Train Station. Excellent location with many amenities nearby includingWalthamstow Shopping Mall,... ** Property Reference: 872639 **</span>
# </a>
#
# <a class="propertyCard-branchLogo-link" data-test="property-branch-logo" href="/estate-agents/agent/OpenRent/London-96668.html" title="OpenRent, London">
# <img alt="OpenRent, London Logo" class="propertyCard-branchLogo-image"/>
# </a>
#
# <a class="sidebarLink-link" href="/property-for-sale/London-87490.html">
# <div class="no-svg-arrow sidebarLink-linkIcon">
# <svg>
# <use xlink:href="#search-icon--arrow"></use>
# </svg>
# </div>
# <span>See properties for sale in London</span>
# </a>
#
# <a class="covid-banner" href="https://www.rightmove.co.uk/news/latest-property-advice" title="Get the latest coronavirus home-moving advice">
# <img alt="Get the latest coronavirus home-moving advice" src="/pvw/images/search/covid_info_banner.7a1b04a043c93791.jpg"/>
# </a>
#
# <a class="sidebarLink-link" data-bind="click: trackRemovalLink" href="/removals.html" title="rightmove.co.uk/removals">
# <div class="no-svg-removal-van sidebarLink-linkIcon">
# <svg>
# <use xlink:href="#search-icon--removal-van"></use>
# </svg>
# </div>
# <span>Removal companies in this area</span>
# </a>
#
# <a class="fraud-link" href="https://www.rightmove.co.uk/advice/safety-and-security/" rel="nofollow" target="_blank" title="Fraud Advice">
#         View our security centre to find out more <span class="fraud-arrow">&gt;</span>
# </a>
#
# <a class="linkBox-bodyLink" href="/house-prices/London-87490.html">View house prices in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490.html">Property to rent in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490/houses.html">Houses to rent in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490/2-bed-houses.html">2 bedroom houses to rent in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490/3-bed-houses.html">3 bedroom houses to rent in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490/4-bed-houses.html">4 bedroom houses to rent in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490/5-bed-houses.html">5+ bedroom houses to rent in London</a>
#
# <a class="linkBox-bodyLink" href="/property-to-rent/London-87490/studio-flats.html">Studio flats to rent in London</a>
#
# <a class="globalFooter-subMenuLink" href="/register.html" nofollow="" title="Sign in / Create account">Sign in / Create account</a>
#
# <a class="globalFooter-subMenuLink" href="/news/" title="Blog">Blog</a>
#
# <a class="globalFooter-subMenuLink" href="https://where.rightmove.co.uk" target="_blank" title="Where can I live?">Where can I live?</a>
#
# <a class="globalFooter-subMenuLink" href="/schools.html" title="Schools">Schools</a>
#
# <a class="globalFooter-subMenuLink" href="/student-accommodation.html" title="Students">Students</a>
#
# <a class="globalFooter-subMenuLink" href="/removals.html" title="Removals">Removals</a>
#
# <a class="globalFooter-subMenuLink" href="/advice/" title="Property guides">Property guides</a>
#
# <a class="globalFooter-subMenuLink" href="/news/house-price-index/" title="House price index">House price index</a>
#
# <a class="globalFooter-subMenuLink" href="/advice/buyer/ways-to-buy/" title="Help to buy">Help to buy</a>
#
# <a class="globalFooter-subMenuLink" href="/advice/landlord/investor-newsletter/" title="Buy to let investors">Buy to let investors</a>
#
# <a class="globalFooter-subMenuLink" href="/cheap-flats-to-rent.html" title="Cheap flats to rent">Cheap flats to rent</a>
#
# <a class="globalFooter-subMenuLink" href="/advice/landlord/investor-newsletter/" title="Property investment">Property investment</a>
#
# <a class="globalFooter-subMenuLink" href="/cheap-houses-for-sale.html" title="Cheap houses for sale">Cheap houses for sale</a>
#
# <a class="globalFooter-subMenuLink" href="/overseas-property.html" title="Overseas">Overseas</a>
#
# <a class="globalFooter-subMenuLink" href="/estate-agents.html" title="Find an agent">Find an agent</a>
#
# <a class="globalFooter-subMenuLink" href="/commercial-property-to-let.html" title="Commercial Property to Let">Commercial Property to Let</a>
#
# <a class="globalFooter-subMenuLink" href="/commercial-property-for-sale.html" title="Commercial Property for Sale">Commercial Property for Sale</a>
#
# <a class="globalFooter-subMenuLink" href="https://plc.rightmove.co.uk/about-us/company-overview.aspx" title="About">About</a>
#
# <a class="globalFooter-subMenuLink" href="/press-centre/" title="Press centre">Press centre</a>
#
# <a class="globalFooter-subMenuLink" href="https://plc.rightmove.co.uk/investors" title="Investor relations">Investor relations</a>
#
# <a class="globalFooter-subMenuLink" href="/rightmoveplc/rightmove-contacts.html" title="Contact us">Contact us</a>
#
# <a class="globalFooter-subMenuLink" href="https://plc.rightmove.co.uk/careers" title="Careers">Careers</a>
#
# <a class="globalFooter-subMenuLink" href="/mobile-platforms.html" title="Mobile apps">Mobile apps</a>
#
# <a class="globalFooter-subMenuLink" href="/property/England.html" title="England">England</a>
#
# <a class="globalFooter-subMenuLink" href="/property/Scotland.html" title="Scotland">Scotland</a>
#
# <a class="globalFooter-subMenuLink" href="/property/Northern-Ireland.html" title="Northern Ireland">Northern Ireland</a>
#
# <a class="globalFooter-subMenuLink" href="/property/Wales.html" title="Wales">Wales</a>
#
# <a class="globalFooter-subMenuLink" href="/property/London.html" title="London">London</a>
#
# <a class="globalFooter-subMenuLink" href="/tube-map.html" title="London stations">London stations</a>
#
# <a class="globalFooter-subMenuLink" href="/overseas-property/in-Spain.html" title="Spain">Spain</a>
#
# <a class="globalFooter-subMenuLink" href="/overseas-property/in-France.html" title="France">France</a>
#
# <a class="globalFooter-subMenuLink" href="/overseas-property/in-Portugal.html" title="Portugal">Portugal</a>
#
# <a class="globalFooter-subMenuLink" href="/overseas-property.html" title="All Countries">All Countries</a>
#
# <a class="globalFooter-subMenuLink" href="/major-cities.html" title="Major towns and cities">Major towns and cities</a>
#
# <a class="globalFooter-subMenuLink" href="https://rmplusportal.rightmove.co.uk" title="Rightmove Plus">Rightmove Plus</a>
#
# <a class="globalFooter-subMenuLink" href="/data/" title="Data Services">Data Services</a>
#
# <a class="globalFooter-subMenuLink" href="/for-agents.html" title="Agents and Developers">Agents and Developers</a>
#
# <a class="globalFooter-subMenuLink" href="/overseas-property/advertise.html" title="Overseas Agents and Developers">Overseas Agents and Developers</a>
#
# <a class="globalFooter-subMenuLink" href="/c/display-advertising/" title="Home and Property Related Services">Home and Property Related Services</a>
#
# <a class="globalFooter-subMenuLink" href="/c/commercial-advertising/" title="Advertise commercial property">Advertise commercial property</a>
#
# <a class="globalFooter-legalLink" href="/site-map.html">Site map</a>
#
# <a class="globalFooter-legalLink globalFooter-legalLink--secondary" href="https://faq.rightmove.co.uk/support/home">Help</a>
#
# <a class="globalFooter-legalLink optanon-show-settings-button optanon-toggle-display" href="/this-site/cookies.html" target="_blank">Cookies</a>
#
# <a class="globalFooter-legalLink globalFooter-legalLink--secondary" href="/advice/safety-and-security/">Safety and security</a>
#
# <a class="globalFooter-legalLink" href="/this-site/terms-of-use.html">Terms of Use</a>
#
# <a class="globalFooter-legalLink" href="/this-site/privacy-policy.html">Privacy Policy</a>
#
# <a href="/this-site/cookies.html">change your cookie settings</a>

# %% [markdown]
# Again, we begin with quite a few hrefs and it's hard to extract any meaning out of them - I would suggest looking at one of the offers and finding a key work to search within the href output.
#
# In my case I looked up a listing directly on the website link (avoid first few ones as they can change in matter of seconds) and found a property with "Belvedere" in it's name - this will surely be present in the desired href, which will take us to the offer.
#
# After searching for "Belvedere" we can see, that the name is found in a 'a' tag, defining a hyperlink with class="propertyCard-link".

# %%
# Let's extract only the 'a' tags with the desired class - we can see that the 5th one is the "Belvedere" property we used to find the reference
bs.findAll("a",{'class':'propertyCard-link'})[4]
# Out:
# <a class="propertyCard-link" data-test="property-details" href="/property-to-rent/property-82780999.html">
# <h2 class="propertyCard-title" itemprop="name">
#             1 bedroom flat share        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Large Double Room - Belvedere Road, SE1" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Large Double Room - Belvedere Road, SE1</span>
# </address>
# </a>

# %%
# We can get the direct hyperlink by calling the 'href' key from attrs dictionary 
bs.findAll("a",{'class':'propertyCard-link'})[0].attrs['href']
# Out:
# '/property-to-rent/property-97203149.html'

# %%
# Let's take a look at the initial 10 links
for item in bs.findAll("a",{'class':'propertyCard-link'})[:10]:

        listing_href=(item.attrs['href'])
        print("{} \n".format(listing_href))
# Out:
# /property-to-rent/property-72233850.html
#
# /property-to-rent/property-72233850.html
#
# /property-to-rent/property-96395564.html
#
# /property-to-rent/property-96395564.html
#
# /property-to-rent/property-94660964.html
#
# /property-to-rent/property-94660964.html
#
# /property-to-rent/property-81144568.html
#
# /property-to-rent/property-81144568.html
#
# /property-to-rent/property-84544456.html
#
# /property-to-rent/property-84544456.html

# %% [markdown]
# The hyperlinks to offers look ok, all we need to do is to add the 'https://www.rightmove.co.uk' adress to them, once we do that you can test them directly in the browser. They will lead you directly to the listings. Let's wrap the whole point up into a single function.

# %%
# The page_urls are fed as list so we can use same function to extract offers from single, or multiple pages
def extract_listing_url(page_urls_list):
    listings_list=[]
    for i in range(0, len(page_urls_list)):
        # Open the page url
        page_url=page_urls_list[i]
        requests.get(page_url)
        page = requests.get(page_url)
        bs = BeautifulSoup(page.text, 'lxml')

        # Extract hyperlinks to all offers from the page
        for item in bs.findAll("a",{'class':'propertyCard-link'}):
            listing_url='https://www.rightmove.co.uk'+(item.attrs['href'])
            listings_list.append(listing_url)
    
    # Get rid of duplicates by changing list into set and back to list
    listings_list=list(set(listings_list))
    
    return(listings_list)

# %%
first_page_listing=extract_listing_url([first_page_url])

# %%
# Check how many offers we managed to extract from a single page - 25 looks ok
len(first_page_listing)
# Out:
# 25

# %% [markdown]
# ## Iterate to next pages

# %% [markdown]
# We are on the last stretch, all we need to do is to get multiple pages with listings. This turned out to be easier than for majority websites as rightmove uses a get API request to display new pages, which means that all the key variables are present in the url.
#
# After comparing first and second pages urls, we can see that the movement between pages is directed by 'index' variable, meaning the index of first displayed offer.. The second page has index of 24, 3rd is 48 and so on. We can create a list of following pages by manipulating the index value.

# %%
def get_n_page_urls(first_page_url,n):
    
    pages_urls_list=[first_page_url]
    for i in range(1,n):
        listing_index=i*24
        nth_page_url=first_page_url+'&index='+str(listing_index)
        pages_urls_list.append(nth_page_url)
    
        
    return(pages_urls_list)

# %%
# Checking the first 5 urls we managed to extract - I recommend pasting one of them as adress to check the outcome
get_n_page_urls(first_page_url,5)
# Out:
# ['https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&minPrice=1000&sortType=1&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords=',
#  'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&minPrice=1000&sortType=1&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords=&index=24',
#  'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&minPrice=1000&sortType=1&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords=&index=48',
#  'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&minPrice=1000&sortType=1&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords=&index=72',
#  'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&minPrice=1000&sortType=1&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords=&index=96']

# %% [markdown]
# ## Extract listings URLs from 10 first pages

# %% [markdown]
# As a last check, let's let's combine steps 2.1 and 2.2 to extract listings urls for first 10 pages.

# %%
# Create list of 10 initial pages
n=10
pages_urls_list=get_n_page_urls(first_page_url,10)

# %%
# Extract listings urls from 10 initial pages
listings_urls_list=extract_listing_url(pages_urls_list)

# %%
# We managed to extract 250 offers - 25 per page, which means everything works as expected
len(listings_urls_list)

# %%
# Let's see first 10
listings_urls_list[:10]

# %% [markdown]
# # Extract data from multiple offer listings

# %% [markdown]
# We have all the components we need:
# - a list of n following page urls
# - listings urls extracted from the page urls
# - function to extract data from a single listing url
#
# All that is left is to combine data from all the listings into a suitable format - a dataframe as prefered for further analysis.
#
# We will do that in two steps, append each listings json to a list, having one list entry containing data in json format for each offer. Then we use json.dumps and json.loads to convert the list of json instances into a df.

# %%
def extract_multiple_listings_data(listings_urls_list):
    json_list = []
    for i in range(0, len(listings_urls_list)):
        # Extract data in json for each listing url
        if np.mod(i,100)==0:
            print("Extraction: {}/{} at:{}".format(i+1,len(listings_urls_list),str(datetime.now())[:-7] ))
        listing_url = listings_urls_list[i]
        listing_json = extract_listing_json(listing_url)
        listing_data = extract_listing_data(listing_json)
        
        # Append data in json to a list
        json_list.append(listing_data)
        
    print("\n------------------------------------------\n")
    print("Sucessfully Extracted: {}/{} offers".format((len(json_list)),i+1))
    
    return(json_list)

# %%
# Test the function on first 100 urls
json_list=extract_multiple_listings_data(listings_urls_list[:100])

# %%
# Each list element is a separate json dictionary contatining the extracted data from one listing
json_list[:5]

# %%
# The last step we need to take is to convert the list into json with json.dumps and then load it into dataframe. 
data_json=json.dumps(json_list)
df=pd.read_json(data_json, orient='id')

# %%
df.head()

# %% [markdown]
# I seems we managed to successfully extract the property data, and transform it into a df.

# %%
df.shape

# %%
df.id.unique().shape

# %% [markdown]
# # Wrap everything up into easy to use Class

# %% [markdown]
# As the code above was written in a format, which aims to make understanding of each step as clear as possible, it is quite messy in terms of usability. We can however transform it into a simple Class, which will allow us the execute the whole scraping process in a few quick steps.

# %%
class Scrape_Rightmove:
    '''
    Class to extract data from listings featured on Rigthmove and convert it to DataFrame. 
    All functions should be executed from top to bottom as they are dependent on each other. 
    '''
    
    def __init__(self, first_page_url, pages_count):
        self.pages_count=pages_count
        self.pages_urls_list=get_n_page_urls(first_page_url,pages_count)
        print("Initialized class to scrape {} pages starting with {}".format(pages_count,first_page_url))
        
    def extract_listings_ulrs(self):
        self.listings_urls_list=extract_listing_url(self.pages_urls_list)
        print("Extracted {} listings from {} pages".format(len(self.listings_urls_list),self.pages_count))
        
    
    def extract_listings_data(self):
        self.json_list=extract_multiple_listings_data(self.listings_urls_list)

        
    def convert_json_to_df(self):
        
        data_json=json.dumps(self.json_list)
        self.df_data=pd.read_json(data_json, orient='id')
        return(self.df_data)

# %%
scrapper = Scrape_Rightmove(first_page_url, 10)

# %%
scrapper.extract_listings_ulrs()

# %%
scrapper.extract_listings_data()

# %%
df=scrapper.convert_json_to_df()

# %%
df.head()

# %%
df.shape

# %%
df.id.unique().shape
